# %% [markdown]
# In this notebook, we will learn how to :
#
# - Clean columns names.
# - Extract and convert numeric values from string values.
# - Extract string data.
# - Work with missing values.

# %% [markdown]
# We'll be working with laptops.csv, a CSV file containing information on about 1,300 laptop computers.

# %%
# !cat laptops.csv | cut -d "," -f 1-7
# Out:
# Manufacturer,Model Name,Category,Screen Size,Screen,CPU,RAM
# Apple,MacBook Pro,Ultrabook,"13.3""",IPS Panel Retina Display 2560x1600,Intel Core i5 2.3GHz,8GB
# Apple,Macbook Air,Ultrabook,"13.3""",1440x900,Intel Core i5 1.8GHz,8GB
# HP,250 G6,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Apple,MacBook Pro,Ultrabook,"15.4""",IPS Panel Retina Display 2880x1800,Intel Core i7 2.7GHz,16GB
# Apple,MacBook Pro,Ultrabook,"13.3""",IPS Panel Retina Display 2560x1600,Intel Core i5 3.1GHz,8GB
# Acer,Aspire 3,Notebook,"15.6""",1366x768,AMD A9-Series 9420 3GHz,4GB
# Apple,MacBook Pro,Ultrabook,"15.4""",IPS Panel Retina Display 2880x1800,Intel Core i7 2.2GHz,16GB
# Apple,Macbook Air,Ultrabook,"13.3""",1440x900,Intel Core i5 1.8GHz,8GB
# Asus,ZenBook UX430UN,Ultrabook,"14.0""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,16GB
# Acer,Swift 3,Ultrabook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# HP,250 G6,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,4GB
# HP,250 G6,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Apple,MacBook Pro,Ultrabook,"15.4""",IPS Panel Retina Display 2880x1800,Intel Core i7 2.8GHz,16GB
# Dell,Inspiron 3567,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Apple,"MacBook 12""",Ultrabook,"12.0""",IPS Panel Retina Display 2304x1440,Intel Core M m3 1.2GHz,8GB
# Apple,MacBook Pro,Ultrabook,"13.3""",IPS Panel Retina Display 2560x1600,Intel Core i5 2.3GHz,8GB
# Dell,Inspiron 3567,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Apple,MacBook Pro,Ultrabook,"15.4""",IPS Panel Retina Display 2880x1800,Intel Core i7 2.9GHz,16GB
# Lenovo,IdeaPad 320-15IKB,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 7100U 2.4GHz,8GB
# Dell,XPS 13,Ultrabook,"13.3""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Asus,Vivobook E200HA,Netbook,"11.6""",1366x768,Intel Atom x5-Z8350 1.44GHz,2GB
# Lenovo,Legion Y520-15IKBN,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 7300HQ 2.5GHz,8GB
# HP,255 G6,Notebook,"15.6""",1366x768,AMD E-Series E2-9000e 1.5GHz,4GB
# Dell,Inspiron 5379,2 in 1 Convertible,"13.3""",Full HD / Touchscreen 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# HP,15-BS101nv (i7-8550U/8GB/256GB/FHD/W10),Ultrabook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Dell,Inspiron 3567,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2GHz,4GB
# Apple,MacBook Air,Ultrabook,"13.3""",1440x900,Intel Core i5 1.6GHz,8GB
# Dell,Inspiron 5570,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Dell,Latitude 5590,Ultrabook,"15.6""",Full HD 1920x1080,Intel Core i7 8650U 1.9GHz,8GB
# HP,ProBook 470,Notebook,"17.3""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Chuwi,"LapBook 15.6""",Notebook,"15.6""",Full HD 1920x1080,Intel Atom x5-Z8300 1.44GHz,4GB
# Asus,E402WA-GA010T (E2-6110/2GB/32GB/W10),Notebook,"14.0""",1366x768,AMD E-Series E2-6110 1.5GHz,2GB
# HP,17-ak001nv (A6-9220/4GB/500GB/Radeon,Notebook,"17.3""",Full HD 1920x1080,AMD A6-Series 9220 2.5GHz,4GB
# Dell,XPS 13,Ultrabook,"13.3""",Touchscreen / Quad HD+ 3200x1800,Intel Core i7 8550U 1.8GHz,16GB
# Apple,MacBook Air,Ultrabook,"13.3""",1440x900,Intel Core i5 1.6GHz,8GB
# Lenovo,IdeaPad 120S-14IAP,Notebook,"14.0""",1366x768,Intel Celeron Dual Core N3350 1.1GHz,4GB
# Acer,Aspire 3,Notebook,"15.6""",1366x768,Intel Core i3 7130U 2.7GHz,4GB
# Dell,Inspiron 5770,Notebook,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# HP,250 G6,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,4GB
# HP,ProBook 450,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Asus,X540UA-DM186 (i3-6006U/4GB/1TB/FHD/Linux),Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Dell,Inspiron 7577,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Asus,X542UQ-GO005 (i5-7200U/8GB/1TB/GeForce,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,8GB
# Acer,Aspire A515-51G,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,4GB
# Dell,Inspiron 7773,2 in 1 Convertible,"17.3""",Full HD / Touchscreen 1920x1080,Intel Core i5 8250U 1.6GHz,12GB
# Apple,MacBook Pro,Ultrabook,"13.3""",IPS Panel Retina Display 2560x1600,Intel Core i5 2.0GHz,8GB
# Lenovo,IdeaPad 320-15ISK,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2GHz,4GB
# Asus,Rog Strix,Gaming,"17.3""",Full HD 1920x1080,AMD Ryzen 1700 3GHz,8GB
# Dell,Inspiron 3567,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,4GB
# Asus,X751NV-TY001T (N4200/4GB/1TB/GeForce,Notebook,"17.3""",1366x768,Intel Pentium Quad Core N4200 1.1GHz,4GB
# Lenovo,Yoga Book,2 in 1 Convertible,"10.1""",IPS Panel Touchscreen 1920x1200,Intel Atom x5-Z8550 1.44GHz,4GB
# Acer,Aspire A515-51G,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# HP,255 G6,Notebook,"15.6""",Full HD 1920x1080,AMD A6-Series 9220 2.5GHz,4GB
# HP,ProBook 430,Notebook,"13.3""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Acer,Aspire 3,Notebook,"15.6""",1366x768,Intel Core i3 7100U 2.4GHz,4GB
# Dell,Inspiron 3576,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# HP,15-bs002nv (i3-6006U/4GB/128GB/FHD/W10),Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Asus,VivoBook Max,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,4GB
# MSI,GS73VR 7RG,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Asus,X541UA-DM1897 (i3-6006U/4GB/256GB/FHD/Linux),Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Dell,Inspiron 5770,Notebook,"17.3""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,16GB
# Dell,Vostro 5471,Ultrabook,"14.0""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Lenovo,IdeaPad 520S-14IKB,Notebook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i3 7130U 2.7GHz,8GB
# Asus,UX410UA-GV350T (i5-8250U/8GB/256GB/FHD/W10),Notebook,"14.0""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# HP,250 G6,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Asus,ZenBook Pro,Ultrabook,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# HP,250 G6,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2GHz,4GB
# HP,Stream 14-AX040wm,Notebook,"14.0""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,4GB
# Lenovo,V310-15ISK (i5-7200U/4GB/1TB/FHD/W10),Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,4GB
# Asus,FX753VE-GC093 (i7-7700HQ/12GB/1TB/GeForce,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,12GB
# Microsoft,Surface Laptop,Ultrabook,"13.5""",Touchscreen 2256x1504,Intel Core i5 7200U 2.5GHz,4GB
# Dell,Inspiron 5370,Ultrabook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Dell,Inspiron 5570,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# MSI,GL72M 7RDX,Gaming,"17.3""",Full HD 1920x1080,Intel Core i5 7300HQ 2.5GHz,8GB
# Acer,Aspire E5-475,Notebook,"14.0""",1366x768,Intel Core i3 6006U 2GHz,8GB
# Asus,FX503VD-E4022T (i7-7700HQ/8GB/1TB/GeForce,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Lenovo,IdeaPad 320-15IKBN,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Dell,Inspiron 5570,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Acer,Aspire A515-51G-32MX,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 7130U 2.7GHz,4GB
# HP,ProBook 470,Notebook,"17.3""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Dell,Latitude 5590,Ultrabook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Apple,"MacBook 12""",Ultrabook,"12.0""",IPS Panel Retina Display 2304x1440,Intel Core i5 1.3GHz,8GB
# HP,ProBook 440,Notebook,"14.0""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Lenovo,IdeaPad 320-15AST,Notebook,"15.6""",Full HD 1920x1080,AMD A6-Series 9220 2.5GHz,4GB
# Acer,Aspire 3,Notebook,"15.6""",1366x768,AMD A9-Series 9420 3GHz,4GB
# Dell,Inspiron 7577,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# HP,Pavilion 15-CK000nv,Ultrabook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# HP,250 G6,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Asus,FX503VM-E4007T (i7-7700HQ/16GB/1TB,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Dell,XPS 13,Ultrabook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Asus,FX550IK-DM018T (FX-9830P/8GB/1TB/Radeon,Gaming,"15.6""",Full HD 1920x1080,AMD FX 9830P 3GHz,8GB
# Acer,Aspire 5,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# HP,Probook 430,Notebook,"13.3""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,16GB
# Dell,Inspiron 7577,Gaming,"15.6""",Full HD 1920x1080,Intel Core i5 7300HQ 2.5GHz,8GB
# Asus,Zenbook UX430UA,Ultrabook,"14.0""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Acer,Spin 5,2 in 1 Convertible,"13.3""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Dell,Inspiron 3567,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Dell,Inspiron 3567,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Asus,X541UV-DM1439T (i3-7100U/6GB/256GB/GeForce,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 7100U 2.4GHz,6GB
# HP,Omen 15-ce007nv,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,12GB
# HP,15-bs017nv (i7-7500U/8GB/256GB/Radeon,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# HP,15-bw000nv (E2-9000e/4GB/500GB/Radeon,Notebook,"15.6""",Full HD 1920x1080,AMD E-Series E2-9000e 1.5GHz,4GB
# Dell,Inspiron 3576,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# HP,Envy 13-ad009n,Ultrabook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Microsoft,Surface Laptop,Ultrabook,"13.5""",Touchscreen 2256x1504,Intel Core i5 7200U 2.5GHz,8GB
# HP,Pavilion 14-BK001nv,Notebook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,6GB
# Lenovo,Ideapad 310-15ISK,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Asus,UX430UQ-GV209R (i7-7500U/8GB/256GB/GeForce,Ultrabook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# MSI,GP62M 7REX,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Lenovo,Thinkpad T470,Notebook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Asus,VivoBook S15,Ultrabook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,16GB
# Dell,XPS 13,Ultrabook,"13.3""",Quad HD+ / Touchscreen 3200x1800,Intel Core i7 7560U 2.4GHz,8GB
# Lenovo,ThinkPad Yoga,2 in 1 Convertible,"13.3""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# HP,Probook 440,Notebook,"14.0""",IPS Panel 1366x768,Intel Core i5 8250U 1.6GHz,4GB
# Dell,XPS 13,Ultrabook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# HP,Spectre x360,2 in 1 Convertible,"13.3""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# HP,Probook 440,Notebook,"14.0""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Dell,Inspiron 7570,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Asus,X705UV-BX074T (i3-6006U/4GB/1TB/GeForce,Notebook,"17.3""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Asus,VivoBook S15,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Acer,Spin 3,Notebook,"15.6""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i3 7100U 2.4GHz,6GB
# MSI,GS63VR 7RG,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Lenovo,IdeaPad 320-15IKBN,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# HP,Probook 470,Notebook,"17.3""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,16GB
# Acer,Aspire 3,Notebook,"15.6""",1366x768,AMD A9-Series 9420 3GHz,4GB
# HP,250 G6,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,4GB
# HP,Probook 440,Notebook,"14.0""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Asus,E402WA-GA007T (E2-6110/4GB/64GB/W10,Notebook,"14.0""",1366x768,AMD E-Series 6110 1.5GHz,4GB
# Dell,Inspiron 5770,Notebook,"17.3""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,16GB
# HP,ProBook 470,Notebook,"17.3""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Dell,Inspiron 5567,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,8GB
# Dell,Inspiron 3567,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Acer,Swift 3,Ultrabook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Acer,Aspire A515-51G-37JS,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 7130U 2.7GHz,4GB
# HP,15-BS078nr (i7-7500U/8GB/1TB/W10),Notebook,"15.6""",1366x768,Intel Core i7 7500U 2.7GHz,8GB
# HP,Probook 440,Notebook,"14.0""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Lenovo,V110-15IAP (N3350/4GB/1TB/No,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3350 1.1GHz,4GB
# Asus,FX753VD-GC086T (i5-7300HQ/8GB/1TB,Gaming,"17.3""",Full HD 1920x1080,Intel Core i5 7300HQ 2.5GHz,8GB
# Lenovo,IdeaPad 320-15IKBN,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,4GB
# HP,Envy 13-AD007nv,Notebook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,4GB
# Acer,Aspire 5,Notebook,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i3 7130U 2.7GHz,4GB
# Lenovo,ThinkPad E480,Notebook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Lenovo,Legion Y520-15IKBN,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Toshiba,Satellite Pro,Notebook,"15.6""",1366x768,Intel Core i5 6200U 2.3GHz,4GB
# HP,255 G6,Notebook,"15.6""",1366x768,AMD A6-Series 9220 2.5GHz,4GB
# Asus,ZenBook UX430UA,Ultrabook,"14.0""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# HP,EliteBook Folio,Ultrabook,"12.5""",IPS Panel 4K Ultra HD / Touchscreen 3840x2160,Intel Core M 6Y75 1.2GHz,8GB
# Asus,X541NA (N3350/4GB/1TB/FHD/W10),Notebook,"15.6""",Full HD 1920x1080,Intel Celeron Dual Core N3350 1.1GHz,4GB
# MSI,GE72MVR 7RG,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Acer,Aspire A315-51,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2GHz,4GB
# Dell,Inspiron 5577,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Dell,Inspiron 7567,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Lenovo,V110-15IKB (i5-7200U/4GB/128GB/W10),Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,4GB
# MSI,GE73VR 7RE,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# HP,EliteBook 840,Ultrabook,"14.0""",Full HD 1920x1080,Intel Core i5 7500U 2.7GHz,4GB
# HP,15-BS103nv (i5-8250U/6GB/256GB/Radeon,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,6GB
# Lenovo,Yoga 520-14IKB,2 in 1 Convertible,"14.0""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i3 7100U 2.4GHz,4GB
# Asus,ZenBook Flip,2 in 1 Convertible,"13.3""",Full HD / Touchscreen 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Dell,Inspiron 5579,2 in 1 Convertible,"15.6""",Full HD / Touchscreen 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Toshiba,Satellite Pro,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2.2GHz,4GB
# Asus,X555BP-XX180T (A9-9420/4GB/1TB/Radeon,Notebook,"15.6""",1366x768,AMD A9-Series 9420 3GHz,4GB
# Acer,Aspire A517-51G,Notebook,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,4GB
# Dell,Inspiron 3576,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Lenovo,Legion Y520-15IKBN,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Acer,Aspire A315-31,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3350 1.1GHz,4GB
# MSI,GE63VR 7RE,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Acer,Aspire 3,Notebook,"15.6""",1366x768,Intel Pentium Quad Core N4200 1.1GHz,4GB
# Dell,Inspiron 5577,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Acer,Aspire A517-51G,Notebook,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# HP,ProBook 430,Notebook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,4GB
# Huawei,MateBook X,Ultrabook,"13.0""",IPS Panel Full HD 2160x1440,Intel Core i5 7200U 2.5GHz,8GB
# HP,17-bs001nv (i5-7200U/6GB/2TB/Radeon,Notebook,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,6GB
# Lenovo,IdeaPad 320-15AST,Notebook,"15.6""",1366x768,AMD A6-Series 9220 2.9GHz,4GB
# Toshiba,Satellite Pro,Notebook,"15.6""",1366x768,Intel Core i3 7100U 2.4GHz,4GB
# HP,ProBook 470,Notebook,"17.3""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Dell,Inspiron 3567,Notebook,"15.6""",1366x768,Intel Core i3 7100U 2.4GHz,8GB
# Acer,Aspire A315-51,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2GHz,4GB
# MSI,GT80S 6QF-074US,Gaming,"18.4""",Full HD 1920x1080,Intel Core i7 6920HQ 2.9GHz,32GB
# Lenovo,V310-15IKB (i5-7200U/8GB/1TB,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# HP,Spectre x360,2 in 1 Convertible,"13.3""",IPS Panel 4K Ultra HD / Touchscreen 3840x2160,Intel Core i5 8250U 1.6GHz,8GB
# Dell,Inspiron 5570,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,16GB
# Dell,XPS 13,Ultrabook,"13.3""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Lenovo,Yoga 920-13IKB,2 in 1 Convertible,"13.9""",IPS Panel 4K Ultra HD / Touchscreen 3840x2160,Intel Core i7 8550U 1.8GHz,16GB
# Toshiba,Satellite Pro,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,8GB
# Xiaomi,Mi Notebook,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Dell,Inspiron 7773,Notebook,"17.3""",Full HD / Touchscreen 1920x1080,Intel Core i7 8550U 1.8GHz,16GB
# Dell,XPS 15,Notebook,"15.6""",4K Ultra HD / Touchscreen 3840x2160,Intel Core i7 7700HQ 2.8GHz,16GB
# Lenovo,Legion Y520-15IKBN,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 7300HQ 2.5GHz,8GB
# Acer,Swift 7,Ultrabook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i5 7Y54 1.2GHz,8GB
# Dell,Inspiron 5770,Notebook,"17.3""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Lenovo,Thinkpad Yoga,2 in 1 Convertible,"14.0""",Touchscreen 2560x1440,Intel Core i7 7500U 2.7GHz,16GB
# Vero,K147 (N3350/4GB/32GB/FHD/W10),Notebook,"14.0""",IPS Panel Full HD 1920x1080,Intel Celeron Dual Core N3350 1.1GHz,4GB
# Xiaomi,Mi Notebook,Ultrabook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Lenovo,IdeaPad 320-17IKBR,Notebook,"17.3""",1600x900,Intel Core i5 8250U 1.6GHz,8GB
# Dell,Inspiron 5379,2 in 1 Convertible,"13.3""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# HP,ProBook 470,Notebook,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Razer,Blade Pro,Gaming,"17.3""",4K Ultra HD / Touchscreen 3840x2160,Intel Core i7 7820HK 2.9GHz,32GB
# HP,ProBook 430,Notebook,"13.3""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# HP,Omen 17-W295,Gaming,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# HP,Probook 470,Notebook,"17.3""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Dell,Inspiron 7577,Gaming,"15.6""",IPS Panel 4K Ultra HD 3840x2160,Intel Core i7 7700HQ 2.8GHz,16GB
# Lenovo,V110-15ISK (i5-6200U/4GB/128GB/W10),Notebook,"15.6""",1366x768,Intel Core i5 6200U 2.3GHz,4GB
# Acer,Aspire E5-576G,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Lenovo,Legion Y720-15IKB,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Dell,Precision 7520,Workstation,"15.6""",4K Ultra HD 3840x2160,Intel Xeon E3-1505M V6 3GHz,16GB
# Lenovo,Legion Y520-15IKBN,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Dell,Inspiron 3567,Notebook,"15.6""",Touchscreen 1366x768,Intel Core i3 7100U 2.4GHz,6GB
# Dell,XPS 13,Ultrabook,"13.3""",IPS Panel 4K Ultra HD / Touchscreen 3840x2160,Intel Core i7 8550U 1.8GHz,8GB
# Dell,XPS 13,Ultrabook,"13.3""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Lenovo,IdeaPad 320-15IKBN,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,8GB
# Acer,Aspire 7,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Asus,ROG GL703VD-GC028T,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# HP,15-bs018nq (i3-6006U/4GB/500GB/FHD/No,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Lenovo,IdeaPad 320-15IKBN,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Huawei,MateBook X,Ultrabook,"13.0""",IPS Panel Full HD 2160x1440,Intel Core i7 7500U 2.7GHz,8GB
# Dell,Inspiron 5370,Ultrabook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Lenovo,IdeaPad 320-17IKB,Notebook,"17.3""",1600x900,Intel Core i5 7200U 2.5GHz,8GB
# HP,Probook 440,Notebook,"14.0""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Dell,Latitude 5490,Ultrabook,"14.0""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Dell,Inspiron 5379,2 in 1 Convertible,"13.3""",Full HD / Touchscreen 1920x1080,Intel Core i7 8550U 1.8GHz,16GB
# Dell,Inspiron 3576,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Lenovo,Yoga 520-14IKB,2 in 1 Convertible,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Toshiba,Portege Z30-C-16L,Ultrabook,"13.3""",Full HD 1920x1080,Intel Core i7 6500U 2.5GHz,8GB
# HP,ProBook 450,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Dell,Alienware 17,Gaming,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Acer,Aspire E5-576G,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Dell,Inspiron 5567,Notebook,"15.6""",Full HD / Touchscreen 1920x1080,Intel Core i7 7500U 2.7GHz,16GB
# Asus,Vivobook X541UV-DM1217T,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Asus,K756UX-T4340T (i5-7200U/8GB/500GB,Notebook,"17.3""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# HP,ZBook 15u,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Asus,Pro P2540UA-XO0198T,Notebook,"15.6""",1366x768,Intel Core i3 7100U 2.4GHz,4GB
# HP,15-rb013nv (E2-9000e/4GB/500GB/W10),Notebook,"15.6""",1366x768,AMD E-Series 9000e 1.5GHz,4GB
# Lenovo,Legion Y720-15IKB,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Dell,Vostro 5468,Notebook,"14.0""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Acer,Aspire R7,2 in 1 Convertible,"13.3""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i5 6200U 2.3GHz,8GB
# Dell,Inspiron 5567,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,16GB
# Acer,Aspire A315-51,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2GHz,4GB
# Asus,X555QG-DM242T (A10-9620P/4GB/1TB,Notebook,"15.6""",Full HD 1920x1080,AMD A10-Series A10-9620P 2.5GHz,4GB
# Asus,ROG G703VI-E5062T,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7820HK 2.9GHz,32GB
# Acer,Nitro AN515-51,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 7300HQ 2.5GHz,8GB
# Lenovo,IdeaPad 320-15ISK,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2GHz,8GB
# Asus,VivoBook Pro,Notebook,"17.3""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Asus,F756UX-T4201D (i7-7500U/8GB/128GB,Notebook,"17.3""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Dell,Inspiron 5577,Gaming,"15.6""",Full HD 1920x1080,Intel Core i5 7300HQ 2.5GHz,8GB
# Lenovo,Yoga 910-13IKB,2 in 1 Convertible,"13.9""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Dell,Inspiron 5570,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# HP,15-bs015dx (i5-7200U/8GB/1TB/W10),Notebook,"15.6""",Touchscreen 1366x768,Intel Core i5 7200U 2.5GHz,8GB
# Asus,Rog G701VIK-BA060T,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7820HK 2.9GHz,16GB
# HP,ProBook 430,Notebook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,4GB
# Apple,MacBook Pro,Ultrabook,"13.3""",IPS Panel Retina Display 2560x1600,Intel Core i5 3.1GHz,8GB
# Dell,Inspiron 5579,2 in 1 Convertible,"15.6""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Asus,ROG G752VSK-GC493T,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Asus,X505BP-BR019T (A9-9420/4GB/1TB/Radeon,Notebook,"15.6""",1366x768,AMD A9-Series 9420 3GHz,4GB
# Lenovo,Yoga 920-13IKB,2 in 1 Convertible,"13.9""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Acer,Aspire 5,Notebook,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i3 7130U 2.7GHz,4GB
# Dell,Vostro 5370,Ultrabook,"13.3""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# HP,15-BW094nd (A6-9220/8GB/128GB/W10),Notebook,"15.6""",1366x768,AMD A6-Series A6-9220 2.5GHz,8GB
# HP,Envy 17-U275cl,Notebook,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,16GB
# MSI,GT73EVR 7RE,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Lenovo,Yoga 720-15IKB,2 in 1 Convertible,"15.6""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Dell,Inspiron 5770,Notebook,"17.3""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Lenovo,IdeaPad 320-15ISK,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# HP,ProBook 450,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,4GB
# Dell,Vostro 3568,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,4GB
# Dell,Inspiron 3567,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Dell,Inspiron 5579,2 in 1 Convertible,"15.6""",Full HD / Touchscreen 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Asus,ZenBook Flip,2 in 1 Convertible,"13.3""",Full HD / Touchscreen 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Lenovo,IdeaPad 320-15IKBN,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,4GB
# HP,Probook 470,Notebook,"17.3""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Lenovo,V330-15IKB (i7-8550U/8GB/256GB/FHD/W10),Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Apple,MacBook Pro,Ultrabook,"13.3""",IPS Panel Retina Display 2560x1600,Intel Core i5 2.9GHz,8GB
# Asus,Rog Strix,Gaming,"17.3""",Full HD 1920x1080,AMD Ryzen 1700 3GHz,16GB
# Dell,Inspiron 3576,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Lenovo,ThinkPad X1,2 in 1 Convertible,"14.0""",Touchscreen 2560x1440,Intel Core i7 6600U 2.6GHz,16GB
# Toshiba,Satellite Pro,Notebook,"15.6""",1366x768,Intel Core i7 6500U 2.5GHz,8GB
# Dell,Inspiron 5567,Notebook,"15.6""",1366x768,Intel Core i7 7500U 2.7GHz,12GB
# Dell,Inspiron 5770,Notebook,"17.3""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Acer,Aspire A515-51G,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Lenovo,IdeaPad 320-17ISK,Notebook,"17.3""",1600x900,Intel Core i3 6006U 2GHz,4GB
# Lenovo,IdeaPad 320-17IKBR,Notebook,"17.3""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Lenovo,IdeaPad 320-17IKB,Notebook,"17.3""",1600x900,Intel Core i7 7500U 2.7GHz,6GB
# Dell,Inspiron 3567,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2.0GHz,4GB
# Lenovo,Legion Y520-15IKBN,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 7300HQ 2.5GHz,8GB
# Lenovo,Ideapad 320-15IKBN,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,6GB
# Acer,Aspire A517-51G,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Acer,SP315-51 (i7-7500U/12GB/1TB/FHD/W10),Notebook,"15.6""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i7 7500U 2.7GHz,12GB
# Lenovo,Thinkpad T570,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Asus,VivoBook S15,Ultrabook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Lenovo,Legion Y520-15IKBN,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Lenovo,IdeaPad 320-15IKB,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Acer,Chromebook C910-C2ST,Notebook,"15.6""",1366x768,Intel Celeron Dual Core 3205U 1.5GHz,2GB
# Asus,FX753VD-GC071T (i7-7700HQ/8GB/1TB/GeForce,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# HP,17-BS037cl (i3-6006U/8GB/1TB/W10),Notebook,"17.3""",1600x900,Intel Core i3 6006U 2GHz,8GB
# Dell,XPS 15,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Lenovo,V330-15IKB (i5-8250U/8GB/256GB/FHD/W10),Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Lenovo,Legion Y720-15IKB,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Acer,Aspire A715-71G,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Dell,Precision 7720,Workstation,"17.3""",Full HD 1920x1080,Intel Core i7 7820HQ 2.9GHz,16GB
# Lenovo,IdeaPad 310-15ABR,Notebook,"15.6""",Full HD 1920x1080,AMD A10-Series 9600P 2.4GHz,6GB
# Asus,ZenBook UX530UQ-PRO,Ultrabook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,16GB
# Asus,VivoBook S14,Notebook,"14.0""",1366x768,Intel Core i3 7100U 2.4GHz,4GB
# Asus,Rog GL702VS-GC095T,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Lenovo,IdeaPad 320-17IKB,Notebook,"17.3""",1600x900,Intel Core i5 7200U 2.5GHz,6GB
# Lenovo,IdeaPad 320-15IKBN,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,8GB
# Asus,GL553VE-FY082T (i7-7700HQ/8GB/1TB,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Lenovo,IdeaPad 320-15IAP,Notebook,"15.6""",1366x768,Intel Pentium Quad Core N4200 1.1GHz,4GB
# HP,EliteBook x360,2 in 1 Convertible,"13.3""",Full HD / Touchscreen 1920x1080,Intel Core i7 7600U 2.8GHz,16GB
# Toshiba,Satellite Pro,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6500U 2.5GHz,8GB
# Lenovo,IdeaPad 320-15IKB,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# HP,250 G6,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Lenovo,IdeaPad 720S-13IKB,Notebook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Dell,XPS 13,Ultrabook,"13.3""",IPS Panel 4K Ultra HD / Touchscreen 3840x2160,Intel Core i7 8550U 1.8GHz,16GB
# MSI,GE63VR 7RF,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Acer,ES1-523-84K7 (A8-7410/8GB/256GB/FHD/W10),Notebook,"15.6""",Full HD 1920x1080,AMD A8-Series 7410 2.2GHz,8GB
# Asus,VivoBook Flip,2 in 1 Convertible,"11.6""",Touchscreen 1366x768,Intel Celeron Dual Core N3350 1.1GHz,2GB
# Dell,Inspiron 5570,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# HP,Spectre x360,2 in 1 Convertible,"13.3""",IPS Panel 4K Ultra HD / Touchscreen 3840x2160,Intel Core i7 8550U 1.8GHz,16GB
# Lenovo,ThinkPad 13,Notebook,"13.3""",1366x768,Intel Celeron Dual Core 3855U 1.6GHz,4GB
# HP,ProBook 640,Notebook,"14.0""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Acer,TravelMate B,Notebook,"11.6""",1366x768,Intel Pentium Quad Core N3710 1.6GHz,4GB
# HP,Elitebook 840,Notebook,"14.0""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Lenovo,IdeaPad 320-17IKB,Notebook,"17.3""",1600x900,Intel Core i5 7200U 2.5GHz,4GB
# Asus,ZenBook UX410UA-GV183T,Notebook,"14.0""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# HP,ProBook 450,Notebook,"15.6""",IPS Panel Full HD 1366x768,Intel Core i7 8550U 1.8GHz,8GB
# Acer,Aspire 5,Notebook,"15.6""",1366x768,AMD A12-Series 9720P 2.7GHz,8GB
# Lenovo,IdeaPad 120S-14IAP,Notebook,"14.0""",1366x768,Intel Celeron Dual Core N3350 1.1GHz,4GB
# Acer,Aspire E5-575,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,6GB
# Asus,VivoBook S15,Ultrabook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# HP,Elitebook 820,Ultrabook,"12.5""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Dell,XPS 15,Notebook,"15.6""",4K Ultra HD / Touchscreen 3840x2160,Intel Core i7 7700HQ 2.8GHz,32GB
# MSI,GL72M 7REX,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Toshiba,Satellite Pro,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Asus,UX510UX-CN269T (i7-7500U/8GB/256GB,Notebook,"14.0""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Lenovo,V310-15ISK (i3-6006U/4GB/1TB/FHD/W10),Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Asus,FX553VD-FY647T (i7-7700HQ/8GB/256GB/GeForce,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# HP,EliteBook 840,Notebook,"14.0""",Full HD 1920x1080,Intel Core i5 7300U 2.6GHz,8GB
# Dell,Inspiron 7570,Ultrabook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# HP,Elitebook 850,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Asus,X541NA (N3350/4GB/1TB/Linux),Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3350 1.1GHz,4GB
# Dell,Inspiron 7570,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Dell,Inspiron 3552,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,4GB
# Lenovo,IdeaPad 320-15ABR,Notebook,"15.6""",Full HD 1920x1080,AMD A12-Series 9720P 3.6GHz,12GB
# HP,ProBook 450,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i3 7100U 2.4GHz,8GB
# Lenovo,Yoga 920-13IKB,2 in 1 Convertible,"13.9""",IPS Panel 4K Ultra HD / Touchscreen 3840x2160,Intel Core i7 8550U 1.8GHz,16GB
# Dell,XPS 13,Ultrabook,"13.3""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Lenovo,Legion Y520-15IKBN,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# HP,Stream 14-AX001nv,Notebook,"14.0""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,2GB
# Dell,Latitude 5590,Ultrabook,"15.6""",Full HD 1920x1080,Intel Core i7 8650U 1.9GHz,16GB
# Asus,VivoBook Flip,2 in 1 Convertible,"11.6""",Touchscreen 1366x768,Intel Celeron Dual Core N3350 1.1GHz,4GB
# Dell,Inspiron 5570,Ultrabook,"15.6""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Dell,XPS 15,Notebook,"15.6""",4K Ultra HD / Touchscreen 3840x2160,Intel Core i7 7700HQ 2.8GHz,16GB
# HP,Elitebook 850,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# MSI,GP72MVR 7RFX,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# HP,Zbook 15,Workstation,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Toshiba,Tecra A50-C-21G,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6500U 2.5GHz,16GB
# Dell,Inspiron 5570,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Lenovo,IdeaPad 320-15IAP,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3350 1.1GHz,4GB
# Dell,Inspiron 7577,Gaming,"15.6""",Full HD 1920x1080,Intel Core i5 7300HQ 2.5GHz,8GB
# Dell,Inspiron 3567,Notebook,"15.6""",Touchscreen 1366x768,Intel Core i5 7200U 2.5GHz,8GB
# Dell,Latitude 7480,Notebook,"14.0""",Full HD 1920x1080,Intel Core i5 7300U 2.6GHz,8GB
# HP,250 G6,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2GHz,4GB
# Asus,Zenbook UX410UA-GV027T,Notebook,"14.0""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Lenovo,IdeaPad 320-17IKB,Notebook,"17.3""",1600x900,Intel Core i5 7200U 2.5GHz,6GB
# HP,250 G6,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Lenovo,IdeaPad 320-15ISK,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2GHz,8GB
# HP,15-AY023na (N3710/8GB/2TB/W10),Notebook,"15.6""",1366x768,Intel Pentium Quad Core N3710 1.6GHz,8GB
# Dell,Inspiron 5770,Notebook,"17.3""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Lenovo,Legion Y520-15IKBN,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 7300HQ 2.5GHz,8GB
# Dell,Inspiron 5567,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# HP,Elitebook 1040,Ultrabook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Asus,ZenBook Flip,2 in 1 Convertible,"15.6""",Full HD / Touchscreen 1920x1080,Intel Core i7 7500U 2.7GHz,12GB
# Acer,Aspire 3,Notebook,"15.6""",1366x768,AMD A9-Series 9420 3GHz,4GB
# Asus,Rog Strix,Gaming,"17.3""",IPS Panel Full HD 1920x1080,AMD Ryzen 1700 3GHz,16GB
# Lenovo,IdeaPad 110-17ACL,Notebook,"17.3""",1600x900,AMD A8-Series 7410 2.2GHz,4GB
# Dell,Inspiron 5379,2 in 1 Convertible,"13.3""",Full HD / Touchscreen 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# HP,15-bw003nv (A9-Series-9420/4GB/256GB/FHD/W10),Notebook,"15.6""",Full HD 1920x1080,AMD A9-Series 9420 3GHz,4GB
# Lenovo,Yoga 11e,Netbook,"11.6""",IPS Panel 1366x768,Intel Celeron Quad Core N3450 1.1GHz,4GB
# Dell,Inspiron 3552,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3060 1.60GHz,4GB
# Asus,VivoBook E403NA,Notebook,"14.0""",1366x768,Intel Celeron Dual Core N3350 1.1GHz,4GB
# Acer,Aspire 7,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# HP,Omen 17-w212nv,Gaming,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Lenovo,V310-15ISK (i3-6006U/4GB/128GB/FHD/No,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Asus,ROG Strix,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Lenovo,IdeaPad 720S-14IKB,Notebook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Asus,Zenbook Flip,Ultrabook,"13.3""",Full HD / Touchscreen 1920x1080,Intel Core i7 7500U 2.7GHz,16GB
# Lenovo,Thinkpad X1,Ultrabook,"14.0""",IPS Panel 2560x1440,Intel Core i7 7500U 2.7GHz,8GB
# Lenovo,Ideapad 510S-13IKB,Notebook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i3 7100U 2.4GHz,4GB
# Dell,Precision 3510,Workstation,"15.6""",Full HD 1920x1080,Intel Core i5 6440HQ 2.6GHz,8GB
# Dell,Precision 5520,Workstation,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6820HQ 2.7GHz,8GB
# Lenovo,ThinkPad X1,2 in 1 Convertible,"14.0""",Touchscreen 2560x1440,Intel Core i7 7500U 2.7GHz,16GB
# Asus,Rog GL753VD-GC042T,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Asus,Rog GL753VE-GC070T,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Acer,Aspire 5,Notebook,"15.6""",IPS Panel 1366x768,Intel Core i5 8250U 1.6GHz,12GB
# MSI,Leopard GP72M,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Dell,Inspiron 5567,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# HP,15-BW004nv (A9-9420/4GB/256GB/Radeon,Ultrabook,"15.6""",Full HD 1920x1080,AMD A9-Series 9420 3GHz,4GB
# Lenovo,ThinkPad E580,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Lenovo,ThinkPad L470,Notebook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Dell,Precision M5520,Workstation,"15.6""",4K Ultra HD / Touchscreen 3840x2160,Intel Core i7 7700HQ 2.8GHz,8GB
# Lenovo,Thinkpad X1,Ultrabook,"14.0""",IPS Panel 2560x1440,Intel Core i7 7500U 2.7GHz,16GB
# Lenovo,IdeaPad 320-15IAP,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3350 1.1GHz,4GB
# Asus,FX753VD-GC461T (i7-7700HQ/16GB/1TB,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Lenovo,ThinkPad E580,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Acer,Aspire 7,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# MSI,GE73VR 7RF,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Asus,Zenbook 3,Ultrabook,"14.0""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Toshiba,Portege Z30-C-16P,Ultrabook,"13.3""",Full HD 1920x1080,Intel Core i7 6500U 2.5GHz,16GB
# Dell,Latitude 7480,Ultrabook,"14.0""",Full HD 1920x1080,Intel Core i7 7600U 2.8GHz,8GB
# Lenovo,IdeaPad 320-15ISK,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Lenovo,Lenovo IdeaPad,Notebook,"11.6""",1366x768,Intel Celeron Dual Core N3350 1.1GHz,2GB
# Lenovo,ThinkPad P51,Workstation,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Lenovo,Thinkpad T470p,Ultrabook,"14.0""",IPS Panel Full HD 2560x1440,Intel Core i7 7700HQ 2.8GHz,8GB
# HP,15-BS028nv (i3-6006U/4GB/1TB/Radeon,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Acer,Aspire R7,2 in 1 Convertible,"13.3""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i7 6500U 2.5GHz,8GB
# Asus,ZenBook Flip,2 in 1 Convertible,"13.3""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Dell,Inspiron 3567,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,4GB
# Dell,Latitude 3380,Notebook,"13.3""",1366x768,Intel Core i3 6006U 2GHz,4GB
# HP,EliteBook 1040,Ultrabook,"14.0""",Full HD 1920x1080,Intel Core i7 6500U 2.5GHz,8GB
# Dell,Inspiron 3567,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,8GB
# Lenovo,ThinkPad E480,Ultrabook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Lenovo,Yoga 720-15IKB,2 in 1 Convertible,"15.6""",IPS Panel 4K Ultra HD / Touchscreen 3840x2160,Intel Core i7 7700HQ 2.8GHz,16GB
# Chuwi,LapBook 12.3,Notebook,"12.3""",IPS Panel Retina Display 2736x1824,Intel Celeron Quad Core N3450 1.1GHz,6GB
# HP,ProBook 650,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7820HQ 2.9GHz,8GB
# Asus,X542UQ-DM117 (i3-7100U/8GB/1TB/GeForce,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 7100U 2.4GHz,8GB
# Dell,Alienware 17,Gaming,"17.3""",IPS Panel 2560x1440,Intel Core i7 7820HK 2.9GHz,16GB
# Dell,Inspiron 7577,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Dell,Inspiron 5570,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Dell,Latitude 5480,Ultrabook,"14.0""",Full HD 1920x1080,Intel Core i7 7600U 2.8GHz,8GB
# HP,Omen 17-w207nv,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,12GB
# Mediacom,FlexBook Edge,2 in 1 Convertible,"11.6""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Celeron Dual Core N3350 1.1GHz,4GB
# Samsung,Chromebook 3,Netbook,"11.6""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,4GB
# Lenovo,Thinkpad 13,Notebook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Lenovo,IdeaPad 320s-14IKB,Notebook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i3 7130U 2.7GHz,4GB
# Lenovo,Thinkpad T570,Workstation,"15.6""",IPS Panel 4K Ultra HD 3840x2160,Intel Core i7 7600U 2.8GHz,16GB
# Lenovo,Thinkpad P51,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7820HQ 2.9GHz,16GB
# Asus,Rog Strix,Gaming,"17.3""",Full HD 1920x1080,AMD Ryzen 1600 3.2GHz,8GB
# HP,15-ra044nv (N3060/4GB/500GB/W10),Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,4GB
# Google,Pixelbook (Core,Ultrabook,"12.3""",Touchscreen 2400x1600,Intel Core i7 7Y75 1.3GHz,16GB
# Lenovo,ThinkPad T470s,Ultrabook,"14.0""",2560x1440,Intel Core i7 7500U 2.7GHz,24GB
# Asus,VivoBook Max,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,4GB
# Lenovo,IdeaPad 320-15AST,Notebook,"17.3""",1600x900,AMD A6-Series 9220 2.5GHz,8GB
# Dell,Inspiron 5570,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,4GB
# Lenovo,ThinkPad X270,Ultrabook,"12.5""",IPS Panel Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Lenovo,IdeaPad 320-15IAP,Notebook,"15.6""",Full HD 1920x1080,Intel Pentium Quad Core N4200 1.1GHz,4GB
# HP,Omen 15-AX205na,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Dell,Latitude 5480,Notebook,"14.0""",Full HD 1920x1080,Intel Core i5 7440HQ 2.8GHz,8GB
# Acer,Aspire ES1-572,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,4GB
# Dell,Precision 3520,Workstation,"15.6""",Full HD 1920x1080,Intel Xeon E3-1505M V6 3GHz,8GB
# MSI,GV62 7RD-1686NL,Gaming,"15.6""",Full HD 1920x1080,Intel Core i5 7300HQ 2.5GHz,8GB
# Microsoft,Surface Laptop,Ultrabook,"13.5""",Touchscreen 2256x1504,Intel Core i7 7660U 2.5GHz,16GB
# HP,15-bs024nv (i5-7200U/8GB/128GB/W10),Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,8GB
# Dell,Precision 3520,Workstation,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6820HQ 2.7GHz,16GB
# HP,ProBook 650,Workstation,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7820HQ 2.9GHz,8GB
# Lenovo,ThinkPad T470,Notebook,"14.0""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Dell,Inspiron 5570,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Dell,Inspiron 3168,2 in 1 Convertible,"11.6""",Touchscreen 1366x768,Intel Pentium Quad Core N3710 1.6GHz,4GB
# Dell,Alienware 17,Notebook,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.7GHz,8GB
# Microsoft,Surface Laptop,Ultrabook,"13.5""",Touchscreen 2256x1504,Intel Core M m3-7Y30 2.2GHz,4GB
# Microsoft,Surface Laptop,Ultrabook,"13.5""",Touchscreen 2256x1504,Intel Core i7 7660U 2.5GHz,8GB
# HP,17-BS092ND (i3-6006U/8GB/256GB/W10),Notebook,"17.3""",1600x900,Intel Core i3 6006U 2GHz,8GB
# Acer,Aspire E5-576G,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# Acer,TravelMate B,Netbook,"11.6""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,4GB
# Asus,Pro P2540UA-AB51,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Lenovo,IdeaPad 510s-14IKB,Notebook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Lenovo,Thinkpad P51,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7820HQ 2.9GHz,8GB
# Asus,X541NA-PD1003Y (N4200/4GB/500GB/W10),Notebook,"15.6""",1366x768,Intel Pentium Quad Core N4200 1.1GHz,4GB
# Acer,Aspire 5,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2GHz,4GB
# Dell,Inspiron 5570,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# HP,Omen 17-an006nv,Gaming,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,12GB
# Lenovo,Thinkpad T460s,Ultrabook,"14.0""",IPS Panel Quad HD+ 2560x1440,Intel Core i7 6600U 2.6GHz,12GB
# HP,Spectre x360,2 in 1 Convertible,"13.3""",IPS Panel 4K Ultra HD / Touchscreen 3840x2160,Intel Core i7 8550U 1.8GHz,8GB
# HP,ZBook 15u,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Google,Pixelbook (Core,Ultrabook,"12.3""",Touchscreen 2400x1600,Intel Core i5 7Y57 1.2GHz,8GB
# Dell,Latitude 7390,Ultrabook,"13.3""",Full HD / Touchscreen 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Asus,ZenBook Pro,Notebook,"15.6""",IPS Panel 4K Ultra HD 3840x2160,Intel Core i7 6700HQ 2.6GHz,12GB
# Dell,Latitude E5470,Notebook,"14.0""",1366x768,Intel Core i3 6100U 2.3GHz,8GB
# Dell,Precision M5520,Workstation,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Lenovo,Thinkpad T470,Notebook,"14.0""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Dell,Inspiron 3576,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Toshiba,Portege X30-D-10J,Notebook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Dell,Inspiron 7570,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# Dell,Vostro 3568,Notebook,"15.6""",1366x768,Intel Core i3 7100U 2.4GHz,4GB
# HP,ProBook 430,Notebook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,4GB
# Chuwi,"Lapbook 15,6",Notebook,"15.6""",Full HD 1920x1080,Intel Atom x5-Z8350 1.44GHz
# Lenovo,ThinkPad E570,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2.0GHz,4GB
# Lenovo,ThinkPad E480,Notebook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Dell,Precision 3520,Workstation,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6820HQ 2.7GHz,16GB
# Dell,XPS 15,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Lenovo,Thinkpad X270,Ultrabook,"12.5""",IPS Panel Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,16GB
# Asus,Zenbook UX390UA,Ultrabook,"12.5""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,16GB
# Lenovo,Thinkpad E570,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Toshiba,Portege X30-D-10L,Ultrabook,"13.3""",Full HD / Touchscreen 1920x1080,Intel Core i7 7500U 2.7GHz,32GB
# Asus,VivoBook Pro,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Acer,Aspire 5,Notebook,"15.6""",1366x768,AMD A10-Series 9620P 2.5GHz,8GB
# Asus,Rog G752VL-UH71T,Gaming,"17.3""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i7 6700HQ 2.6GHz,24GB
# Lenovo,Thinkpad X260,Ultrabook,"12.5""",IPS Panel 1366x768,Intel Core i5 6200U 2.3GHz,8GB
# Lenovo,Ideapad 520-15IKBR,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,8GB
# HP,EliteBook 840,Notebook,"14.0""",Full HD 1920x1080,Intel Core i7 7600U 2.8GHz,8GB
# Lenovo,ThinkPad 13,Notebook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i3 7100U 2.4GHz,8GB
# Lenovo,ThinkPad L570,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Asus,VivoBook E201NA,Netbook,"11.6""",1366x768,Intel Celeron Dual Core N3350 1.1GHz,4GB
# HP,15-BS026nv (i5-7200U/8GB/256GB/Radeon,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,8GB
# Lenovo,Yoga 920-13IKB,2 in 1 Convertible,"13.9""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i5 8250U 1.6GHz,8GB
# Lenovo,IdeaPad 320-14IAP,Notebook,"14.0""",1366x768,Intel Celeron Dual Core N3350 1.1GHz,4GB
# Lenovo,Chromebook N23,Netbook,"11.6""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,4GB
# Lenovo,ThinkPad 13,Notebook,"13.3""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Asus,ZenBook UX510UX-CN211T,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Acer,Aspire A515-51G-59QF,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,4GB
# HP,Envy 13-AB002nv,Ultrabook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Lenovo,Legion Y520-15IKBN,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Dell,XPS 13,Ultrabook,"13.3""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Acer,Aspire A515-51G,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,4GB
# Dell,Vostro 5568,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Dell,Inspiron 5570,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,16GB
# ...
# Lenovo,IdeaPad 500-15ISK,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 6500U 2.5GHz,16GB
# HP,ZBook 17,Workstation,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,8GB
# Dell,Inspiron 5567,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,8GB
# MSI,GT72S Dominator,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 6820HQ 2.7GHz,16GB
# HP,EliteBook 850,Ultrabook,"15.6""",Full HD 1920x1080,Intel Core i7 6500U 2.5GHz,8GB
# Lenovo,ThinkPad X1,2 in 1 Convertible,"14.0""",IPS Panel Touchscreen 2560x1440,Intel Core i7 6600U 2.6GHz,16GB
# MSI,GP62M 7RDX,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# HP,Spectre Pro,2 in 1 Convertible,"13.3""",Full HD / Touchscreen 1920x1080,Intel Core i5 6300U 2.4GHz,8GB
# HP,ZBook 15,Workstation,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,8GB
# HP,Spectre Pro,2 in 1 Convertible,"13.3""",Touchscreen 2560x1440,Intel Core i7 6600U 2.6GHz,8GB
# HP,ZBook Studio,Workstation,"15.6""",Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,8GB
# HP,EliteBook 820,Ultrabook,"12.5""",Full HD 1920x1080,Intel Core i7 6500U 2.50GHz,8GB
# Dell,Vostro 5568,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# HP,EliteBook 850,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 6200U 2.3GHz,8GB
# Lenovo,ThinkPad X1,2 in 1 Convertible,"14.0""",IPS Panel Touchscreen 2560x1440,Intel Core i7 6500U 2.5GHz,8GB
# Lenovo,V110-15ISK (i3-6006U/4GB/1TB/No,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2.0GHz,4GB
# HP,15-BA015wm (E2-7110/4GB/500GB/W10),Notebook,"15.6""",1366x768,AMD E-Series 7110 1.8GHz,4GB
# Lenovo,B51-80 (i5-6200U/8GB/1TB/Radeon,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 6200U 2.3GHz,8GB
# Dell,Inspiron 7567,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Dell,XPS 15,Notebook,"15.6""",IPS Panel Touchscreen / 4K Ultra HD 3840x2160,Intel Core i5 6300HQ 2.3GHz,8GB
# HP,15-bw002nv (A6-9220/4GB/256GB/Radeon,Notebook,"15.6""",Full HD 1920x1080,AMD A6-Series A6-9220 2.5GHz,4GB
# MSI,GP72M 7REX,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Lenovo,ThinkPad T460s,Ultrabook,"14.0""",Full HD 1920x1080,Intel Core i7 6600U 2.6GHz,12GB
# Lenovo,B51-80 (i5-6200U/8GB/1008GB/Radeon,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 6200U 2.3GHz,8GB
# HP,Spectre Pro,2 in 1 Convertible,"13.3""",Touchscreen 2560x1440,Intel Core i7 6600U 2.6GHz,8GB
# Lenovo,ThinkPad T460,Ultrabook,"14.0""",Full HD 1920x1080,Intel Core i7 6600U 2.6GHz,8GB
# MSI,GS40 Phantom,Gaming,"14.0""",Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,16GB
# HP,Pavilion 15-cb003nv,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Lenovo,IdeaPad 310-15ISK,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2.0GHz,8GB
# HP,250 G4,Notebook,"15.6""",1366x768,Intel Core i5 6200U 2.3GHz,4GB
# Dell,Inspiron 7567,Gaming,"15.6""",4K Ultra HD 3840x2160,Intel Core i7 7700HQ 2.8GHz,8GB
# Lenovo,ThinkPad T570,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Lenovo,320-15ISK (i3-6006U/4GB/1TB/GeForce,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# HP,Stream 14-AX000nv,Notebook,"14.0""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,2GB
# MSI,PL60 7RD,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# HP,250 G5,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 6500U 2.5GHz,8GB
# HP,ProBook 450,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,16GB
# Asus,X553SA-XX021T (N3050/4GB/500GB/W10),Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3050 1.6GHz,4GB
# Lenovo,V110-15ISK (i5-6200U/4GB/500GB/No,Notebook,"15.6""",1366x768,Intel Core i5 6200U 2.3GHz,4GB
# Lenovo,IdeaPad 510-15IKB,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Asus,UX410UA-GV097T (i3-7100U/4GB/256GB/FHD/W10),Notebook,"14.0""",Full HD 1920x1080,Intel Core i3 7100U 2.4GHz,4GB
# Lenovo,B51-80 (i7-6500U/4GB/1008GB/FHD/W7),Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 6500U 2.5GHz,4GB
# Lenovo,IdeaPad Y700-15ISK,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,16GB
# MSI,GS60 Ghost,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,16GB
# HP,ProBook 450,Notebook,"15.6""",1366x768,Intel Core i3 6100U 2.3GHz,4GB
# Lenovo,ThinkPad X1,2 in 1 Convertible,"14.0""",IPS Panel Touchscreen 2560x1440,Intel Core i5 6200U 2.3GHz,8GB
# Lenovo,IdeaPad 310-15IKB,Ultrabook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,6GB
# Dell,Vostro 5568,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB
# Acer,Aspire 3,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3350 2GHz,4GB
# HP,Pavilion 15-BC000nv,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,6GB
# Asus,Rog GL552VW-DM201T,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,8GB
# Dell,Inspiron 5578,2 in 1 Convertible,"15.6""",Full HD / Touchscreen 1920x1080,Intel Core i7 7500U 2.7GHz,16GB
# Acer,Aspire E5-576G,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,4GB
# Dell,XPS 13,Ultrabook,"13.3""",Quad HD+ / Touchscreen 3200x1800,Intel Core i5 6300U 2.4GHz,8GB
# Acer,Predator G9-793,Gaming,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Lenovo,Legion Y520-15IKBN,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 7300HQ 2.5GHz,8GB
# Samsung,Chromebook Plus,2 in 1 Convertible,"12.3""",IPS Panel Touchscreen 2400x1600,Samsung Cortex A72&A53 2.0GHz,4GB
# HP,250 G6,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,4GB
# Apple,"MacBook 12""",Ultrabook,"12.0""",IPS Panel Retina Display 2304x1440,Intel Core M 1.1GHz,8GB
# Dell,Inspiron 7378,2 in 1 Convertible,"13.3""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# HP,Pavilion Power,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,12GB
# Lenovo,V110-15ISK (i3-6006U/4GB/1TB/Radeon,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2GHz,4GB
# Asus,Rog G752VY-GC229T,Gaming,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,16GB
# Acer,Aspire 3,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3350 2GHz,4GB
# MSI,GS73VR 7RF,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Dell,Inspiron 5567,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2.0GHz,4GB
# Lenovo,IdeaPad 310-15ISK,Notebook,"15.6""",1366x768,Intel Core i7 6500U 2.5GHz,8GB
# Dell,Inspiron 5579,2 in 1 Convertible,"15.6""",Full HD / Touchscreen 1920x1080,Intel Core i7 8550U 1.8GHz,16GB
# Dell,XPS 13,Ultrabook,"13.3""",Quad HD+ / Touchscreen 3200x1800,Intel Core i7 7500U 2.7GHz,16GB
# Asus,FX502VM-DM105T (i7-6700HQ/8GB/1TB/GeForce,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,8GB
# Dell,Inspiron 5567,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# HP,15-bs025nv (i5-7200U/8GB/256GB/W10),Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,8GB
# Lenovo,IdeaPad 320-15AST,Notebook,"15.6""",1366x768,AMD E-Series 9000 2.2GHz,4GB
# Acer,Aspire E5-774G,Notebook,"17.3""",1600x900,Intel Core i3 6006U 2.0GHz,8GB
# Asus,Rog Strix,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Apple,"MacBook 12""",Ultrabook,"12.0""",IPS Panel Retina Display 2304x1440,Intel Core M 1.2GHz,8GB
# Asus,FX502VM-AS73 (i7-7700HQ/16GB/1TB,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# MSI,GS73VR Stealth,Gaming,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,16GB
# Dell,Inspiron 7579,2 in 1 Convertible,"15.6""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Asus,ROG Strix,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Acer,C740-C9QX (3205U/2GB/32GB/Chrome,Netbook,"11.6""",1366x768,Intel Celeron Dual Core 3205U 1.5GHz,2GB
# Acer,E5 774G,Notebook,"17.3""",1600x900,Intel Core i3 6006U 2GHz,4GB
# Lenovo,IdeaPad 320-17IKB,Notebook,"17.3""",1600x900,Intel Core i5 7200U 2.5GHz,8GB
# Lenovo,IdeaPad Y700-15ISK,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,8GB
# Acer,SP714-51 (i7-7Y75/8GB/256GB/FHD/W10),2 in 1 Convertible,"14.0""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i7 7Y75 1.3GHz,8GB
# Lenovo,Thinkpad T560,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6600U 2.6GHz,8GB
# MSI,GP62MVR 6RF,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,8GB
# HP,15-bw009nv (A12-9720P/6GB/1TB/Radeon,Notebook,"15.6""",Full HD 1920x1080,AMD A12-Series 9720P 2.7GHz,6GB
# Dell,Latitude E7270,Ultrabook,"12.5""",Full HD / Touchscreen 1920x1080,Intel Core i5 6300U 2.4GHz,8GB
# Dell,Inspiron 5578,2 in 1 Convertible,"15.0""",Full HD / Touchscreen 1920x1080,Intel Core i3 7100U 2.4GHz,4GB
# Asus,X540SA-RBPDN09 (N3710/4GB/1TB/W10),Notebook,"15.6""",1366x768,Intel Pentium Quad Core N3710 1.6GHz,4GB
# Dell,XPS 13,Ultrabook,"13.3""",Quad HD+ / Touchscreen 3200x1800,Intel Core i7 7500U 2.7GHz,8GB
# Dell,Vostro 3568,Notebook,"15.6""",1366x768,Intel Core i5 7200U 2.5GHz,4GB
# Lenovo,IdeaPad Y700-15ISK,Gaming,"15.6""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i7 6700HQ 2.6GHz,16GB
# MSI,GL62M 7RDX,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,8GB
# Lenovo,ThinkPad Yoga,Netbook,"12.5""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i7 6500U 2.50GHz,16GB
# Razer,Blade Pro,Gaming,"14.0""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Dell,Inspiron 3567,Notebook,"15.6""",Touchscreen 1366x768,Intel Core i3 7100U 2.4GHz,8GB
# MSI,GE72VR Apache,Gaming,"17.3""",Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Apple,MacBook Air,Ultrabook,"11.6""",1366x768,Intel Core i5 1.6GHz,4GB
# HP,15-bs023nv (i3-6006U/4GB/1TB/FHD/W10),Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB
# HP,EliteBook 840,Ultrabook,"14.0""",2560x1440,Intel Core i7 6500U 2.5GHz,8GB
# Dell,Vostro 3559,Notebook,"15.6""",1366x768,Intel Core i5 6200U 2.3GHz,4GB
# MSI,GL62 6QF,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,8GB
# Lenovo,ThinkPad 13,Notebook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,16GB
# Lenovo,IdeaPad 320-15ABR,Notebook,"15.6""",Full HD 1920x1080,AMD A12-Series 9720P 3.6GHz,6GB
# Asus,ZenBook UX310UA-WB71,Ultrabook,"13.3""",Full HD 1920x1080,Intel Core i7 6500U 2.5GHz,8GB
# Acer,Aspire ES1-572,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2.0GHz,4GB
# Dell,Inspiron 7779,2 in 1 Convertible,"17.3""",Full HD / Touchscreen 1920x1080,Intel Core i7 7500U 2.7GHz,16GB
# HP,EliteBook 840,Notebook,"14.0""",Full HD 1920x1080,Intel Core i5 6200U 2.3GHz,4GB
# Asus,Rog GL553VE-FY052T,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 7700HQ 2.8GHz,16GB
# Dell,Latitude 5480,Notebook,"14.0""",1366x768,Intel Core i5 7200U 2.5GHz,4GB
# Asus,Rog GL502VS,Gaming,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,16GB
# Lenovo,V510-15IKB (i5-7200U/8GB/256GB/FHD/No,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB
# Dell,XPS 13,2 in 1 Convertible,"13.3""",Quad HD+ / Touchscreen 3200x1800,Intel Core i5 7Y54 1.2GHz,8GB
# Dell,Inspiron 3552,Notebook,"15.6""",1366x768,Intel Pentium Quad Core N3710 1.6GHz,4GB
# HP,255 G6,Notebook,"15.6""",1366x768,AMD A6-Series 9220 2.5GHz,4GB
# Lenovo,IdeaPad 310-15ISK,Notebook,"15.6""",Full HD 1920x1080,Intel Core i3 6100U 2.3GHz,6GB
# Lenovo,ThinkPad L460,Notebook,"14.0""",IPS Panel Full HD 1920x1080,Intel Core i5 6200U 2.3GHz,8GB
# Dell,Inspiron 3552,Notebook,"15.6""",1366x768,Intel Pentium Quad Core N3700 1.6GHz,4GB
# Asus,X541NA-GO020T (N3350/4GB/1TB/W10),Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3350 1.1GHz,4GB
# Asus,Rog G752VT-GC073T,Gaming,"17.3""",IPS Panel Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,16GB
# Dell,Vostro 3568,Notebook,"15.6""",1366x768,Intel Core i3 6006U 2GHz,4GB
# Lenovo,B51-80 (i7-6500U/8GB/1008GB/Radeon,Notebook,"15.6""",Full HD 1920x1080,Intel Core i7 6500U 2.5GHz,8GB
# MSI,GE62 Apache,Gaming,"15.6""",Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,8GB
# Lenovo,Yoga 500-14IBD,2 in 1 Convertible,"14.0""",Full HD / Touchscreen 1920x1080,Intel Core i5 6200U 2.3GHz,4GB
# Asus,ZenBook UX305CA-UBM1,Ultrabook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core M 6Y30 0.9GHz,8GB
# Dell,Inspiron 3567,Notebook,"15.6""",1366x768,Intel Core i3 7100U 2.4GHz,6GB
# Acer,Aspire ES1-531,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,4GB
# Dell,Inspiron 3552,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3050 1.6GHz,2GB
# Lenovo,IdeaPad Y700-15ISK,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,8GB
# HP,Pavilion 15-AW003nv,Notebook,"15.6""",Full HD 1920x1080,AMD A9-Series 9410 2.9GHz,6GB
# Dell,Inspiron 3567,Notebook,"15.6""",1366x768,Intel Core i7 7500U 2.7GHz,8GB
# HP,Stream 11-Y000na,Netbook,"11.6""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,2GB
# Asus,X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce,Notebook,"15.6""",1366x768,Intel Core i7 6500U 2.5GHz,4GB
# Lenovo,Yoga 500-14ISK,2 in 1 Convertible,"14.0""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i7 6500U 2.5GHz,4GB
# Lenovo,Yoga 900-13ISK,2 in 1 Convertible,"13.3""",IPS Panel Quad HD+ / Touchscreen 3200x1800,Intel Core i7 6500U 2.5GHz,16GB
# Lenovo,IdeaPad 100S-14IBR,Notebook,"14.0""",1366x768,Intel Celeron Dual Core N3050 1.6GHz,2GB
# HP,15-AC110nv (i7-6500U/6GB/1TB/Radeon,Notebook,"15.6""",1366x768,Intel Core i7 6500U 2.5GHz,6GB
# Asus,X553SA-XX031T (N3050/4GB/500GB/W10),Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3050 1.6GHz,4GB
# Asus,ZenBook UX305CA-UBM1,Ultrabook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core M 6Y30 0.9GHz,8GB
# Dell,Inspiron 3567,Notebook,"15.6""",1366x768,Intel Core i3 7100U 2.4GHz,6GB
# Acer,Aspire ES1-531,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,4GB
# Dell,Inspiron 3552,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3050 1.6GHz,2GB
# Lenovo,IdeaPad Y700-15ISK,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,8GB
# HP,Pavilion 15-AW003nv,Notebook,"15.6""",Full HD 1920x1080,AMD A9-Series 9410 2.9GHz,6GB
# Dell,Inspiron 3567,Notebook,"15.6""",1366x768,Intel Core i7 7500U 2.7GHz,8GB
# HP,Stream 11-Y000na,Netbook,"11.6""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,2GB
# Asus,X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce,Notebook,"15.6""",1366x768,Intel Core i7 6500U 2.5GHz,4GB
# Lenovo,Yoga 500-14ISK,2 in 1 Convertible,"14.0""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i7 6500U 2.5GHz,4GB
# Lenovo,Yoga 900-13ISK,2 in 1 Convertible,"13.3""",IPS Panel Quad HD+ / Touchscreen 3200x1800,Intel Core i7 6500U 2.5GHz,16GB
# Lenovo,IdeaPad 100S-14IBR,Notebook,"14.0""",1366x768,Intel Celeron Dual Core N3050 1.6GHz,2GB
# HP,15-AC110nv (i7-6500U/6GB/1TB/Radeon,Notebook,"15.6""",1366x768,Intel Core i7 6500U 2.5GHz,6GB
# Asus,X553SA-XX031T (N3050/4GB/500GB/W10),Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3050 1.6GHz,4GB
# Asus,ZenBook UX305CA-UBM1,Ultrabook,"13.3""",IPS Panel Full HD 1920x1080,Intel Core M 6Y30 0.9GHz,8GB
# Dell,Inspiron 3567,Notebook,"15.6""",1366x768,Intel Core i3 7100U 2.4GHz,6GB
# Acer,Aspire ES1-531,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,4GB
# Dell,Inspiron 3552,Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3050 1.6GHz,2GB
# Lenovo,IdeaPad Y700-15ISK,Notebook,"15.6""",IPS Panel Full HD 1920x1080,Intel Core i7 6700HQ 2.6GHz,8GB
# HP,Pavilion 15-AW003nv,Notebook,"15.6""",Full HD 1920x1080,AMD A9-Series 9410 2.9GHz,6GB
# Dell,Inspiron 3567,Notebook,"15.6""",1366x768,Intel Core i7 7500U 2.7GHz,8GB
# HP,Stream 11-Y000na,Netbook,"11.6""",1366x768,Intel Celeron Dual Core N3060 1.6GHz,2GB
# Asus,X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce,Notebook,"15.6""",1366x768,Intel Core i7 6500U 2.5GHz,4GB
# Lenovo,Yoga 500-14ISK,2 in 1 Convertible,"14.0""",IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i7 6500U 2.5GHz,4GB
# Lenovo,Yoga 900-13ISK,2 in 1 Convertible,"13.3""",IPS Panel Quad HD+ / Touchscreen 3200x1800,Intel Core i7 6500U 2.5GHz,16GB
# Lenovo,IdeaPad 100S-14IBR,Notebook,"14.0""",1366x768,Intel Celeron Dual Core N3050 1.6GHz,2GB
# HP,15-AC110nv (i7-6500U/6GB/1TB/Radeon,Notebook,"15.6""",1366x768,Intel Core i7 6500U 2.5GHz,6GB
# Asus,X553SA-XX031T (N3050/4GB/500GB/W10),Notebook,"15.6""",1366x768,Intel Celeron Dual Core N3050 1.6GHz,4GB

# %% [markdown]
# ## Reading CSV Files with Encodings

# %% [markdown]
# We can start by reading the data into pandas. Let's look at what happens when we use pandas.read_csv() function with only the filename argument:

# %%
import numpy as np
import pandas as pd

# %%
laptops = pd.read_csv("laptops.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 4: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-28280099abad> in <module>()
# ----> 1 laptops = pd.read_csv("laptops.csv")
#
# c:\users\administrator\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# c:\users\administrator\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# c:\users\administrator\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# c:\users\administrator\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 4: invalid continuation byte

# %% [markdown]
# We get an error! Since the file we try to read was not coded in 'utf-8'. To properly read data in this file, we need to specify the correct encoding that was used to encode the data in the file.

# %%
laptops = pd.read_csv("laptops.csv", encoding="latin-1")
laptops
# Out:
#      Manufacturer                                 Model Name  \
# 0           Apple                                MacBook Pro
# 1           Apple                                Macbook Air
# 2              HP                                     250 G6
# 3           Apple                                MacBook Pro
# 4           Apple                                MacBook Pro
# 5            Acer                                   Aspire 3
# 6           Apple                                MacBook Pro
# 7           Apple                                Macbook Air
# 8            Asus                            ZenBook UX430UN
# 9            Acer                                    Swift 3
# 10             HP                                     250 G6
# 11             HP                                     250 G6
# 12          Apple                                MacBook Pro
# 13           Dell                              Inspiron 3567
# 14          Apple                                MacBook 12"
# 15          Apple                                MacBook Pro
# 16           Dell                              Inspiron 3567
# 17          Apple                                MacBook Pro
# 18         Lenovo                          IdeaPad 320-15IKB
# 19           Dell                                     XPS 13
# 20           Asus                            Vivobook E200HA
# 21         Lenovo                         Legion Y520-15IKBN
# 22             HP                                     255 G6
# 23           Dell                              Inspiron 5379
# 24             HP    15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)
# 25           Dell                              Inspiron 3567
# 26          Apple                                MacBook Air
# 27           Dell                              Inspiron 5570
# 28           Dell                              Latitude 5590
# 29             HP                                ProBook 470
# ...           ...                                        ...
# 1273           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1274         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 1275         Asus                       ZenBook UX305CA-UBM1
# 1276         Dell                              Inspiron 3567
# 1277         Acer                             Aspire ES1-531
# 1278         Dell                              Inspiron 3552
# 1279       Lenovo                         IdeaPad Y700-15ISK
# 1280           HP                        Pavilion 15-AW003nv
# 1281         Dell                              Inspiron 3567
# 1282           HP                           Stream 11-Y000na
# 1283         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1284       Lenovo                             Yoga 500-14ISK
# 1285       Lenovo                             Yoga 900-13ISK
# 1286       Lenovo                         IdeaPad 100S-14IBR
# 1287           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1288         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 1289         Asus                       ZenBook UX305CA-UBM1
# 1290         Dell                              Inspiron 3567
# 1291         Acer                             Aspire ES1-531
# 1292         Dell                              Inspiron 3552
# 1293       Lenovo                         IdeaPad Y700-15ISK
# 1294           HP                        Pavilion 15-AW003nv
# 1295         Dell                              Inspiron 3567
# 1296           HP                           Stream 11-Y000na
# 1297         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1298       Lenovo                             Yoga 500-14ISK
# 1299       Lenovo                             Yoga 900-13ISK
# 1300       Lenovo                         IdeaPad 100S-14IBR
# 1301           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 Category Screen Size  \
# 0              Ultrabook       13.3"
# 1              Ultrabook       13.3"
# 2               Notebook       15.6"
# 3              Ultrabook       15.4"
# 4              Ultrabook       13.3"
# 5               Notebook       15.6"
# 6              Ultrabook       15.4"
# 7              Ultrabook       13.3"
# 8              Ultrabook       14.0"
# 9              Ultrabook       14.0"
# 10              Notebook       15.6"
# 11              Notebook       15.6"
# 12             Ultrabook       15.4"
# 13              Notebook       15.6"
# 14             Ultrabook       12.0"
# 15             Ultrabook       13.3"
# 16              Notebook       15.6"
# 17             Ultrabook       15.4"
# 18              Notebook       15.6"
# 19             Ultrabook       13.3"
# 20               Netbook       11.6"
# 21                Gaming       15.6"
# 22              Notebook       15.6"
# 23    2 in 1 Convertible       13.3"
# 24             Ultrabook       15.6"
# 25              Notebook       15.6"
# 26             Ultrabook       13.3"
# 27              Notebook       15.6"
# 28             Ultrabook       15.6"
# 29              Notebook       17.3"
# ...                  ...         ...
# 1273            Notebook       15.6"
# 1274            Notebook       15.6"
# 1275           Ultrabook       13.3"
# 1276            Notebook       15.6"
# 1277            Notebook       15.6"
# 1278            Notebook       15.6"
# 1279            Notebook       15.6"
# 1280            Notebook       15.6"
# 1281            Notebook       15.6"
# 1282             Netbook       11.6"
# 1283            Notebook       15.6"
# 1284  2 in 1 Convertible       14.0"
# 1285  2 in 1 Convertible       13.3"
# 1286            Notebook       14.0"
# 1287            Notebook       15.6"
# 1288            Notebook       15.6"
# 1289           Ultrabook       13.3"
# 1290            Notebook       15.6"
# 1291            Notebook       15.6"
# 1292            Notebook       15.6"
# 1293            Notebook       15.6"
# 1294            Notebook       15.6"
# 1295            Notebook       15.6"
# 1296             Netbook       11.6"
# 1297            Notebook       15.6"
# 1298  2 in 1 Convertible       14.0"
# 1299  2 in 1 Convertible       13.3"
# 1300            Notebook       14.0"
# 1301            Notebook       15.6"
# 1302            Notebook       15.6"
#
#                                           Screen  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# 5                                       1366x768
# 6             IPS Panel Retina Display 2880x1800
# 7                                       1440x900
# 8                              Full HD 1920x1080
# 9                    IPS Panel Full HD 1920x1080
# 10                                      1366x768
# 11                             Full HD 1920x1080
# 12            IPS Panel Retina Display 2880x1800
# 13                             Full HD 1920x1080
# 14            IPS Panel Retina Display 2304x1440
# 15            IPS Panel Retina Display 2560x1600
# 16                             Full HD 1920x1080
# 17            IPS Panel Retina Display 2880x1800
# 18                             Full HD 1920x1080
# 19     IPS Panel Full HD / Touchscreen 1920x1080
# 20                                      1366x768
# 21                   IPS Panel Full HD 1920x1080
# 22                                      1366x768
# 23               Full HD / Touchscreen 1920x1080
# 24                             Full HD 1920x1080
# 25                                      1366x768
# 26                                      1440x900
# 27                             Full HD 1920x1080
# 28                             Full HD 1920x1080
# 29                             Full HD 1920x1080
# ...                                          ...
# 1273                                    1366x768
# 1274                                    1366x768
# 1275                 IPS Panel Full HD 1920x1080
# 1276                                    1366x768
# 1277                                    1366x768
# 1278                                    1366x768
# 1279                 IPS Panel Full HD 1920x1080
# 1280                           Full HD 1920x1080
# 1281                                    1366x768
# 1282                                    1366x768
# 1283                                    1366x768
# 1284   IPS Panel Full HD / Touchscreen 1920x1080
# 1285  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1286                                    1366x768
# 1287                                    1366x768
# 1288                                    1366x768
# 1289                 IPS Panel Full HD 1920x1080
# 1290                                    1366x768
# 1291                                    1366x768
# 1292                                    1366x768
# 1293                 IPS Panel Full HD 1920x1080
# 1294                           Full HD 1920x1080
# 1295                                    1366x768
# 1296                                    1366x768
# 1297                                    1366x768
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        CPU   RAM                 Storage  \
# 0                     Intel Core i5 2.3GHz   8GB               128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB     128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB               256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB               512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB               256GB SSD
# 5                  AMD A9-Series 9420 3GHz   4GB               500GB HDD
# 6                     Intel Core i7 2.2GHz  16GB     256GB Flash Storage
# 7                     Intel Core i5 1.8GHz   8GB     256GB Flash Storage
# 8               Intel Core i7 8550U 1.8GHz  16GB               512GB SSD
# 9               Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 10              Intel Core i5 7200U 2.5GHz   4GB               500GB HDD
# 11                Intel Core i3 6006U 2GHz   4GB               500GB HDD
# 12                    Intel Core i7 2.8GHz  16GB               256GB SSD
# 13                Intel Core i3 6006U 2GHz   4GB               256GB SSD
# 14                  Intel Core M m3 1.2GHz   8GB               256GB SSD
# 15                    Intel Core i5 2.3GHz   8GB               256GB SSD
# 16              Intel Core i7 7500U 2.7GHz   8GB               256GB SSD
# 17                    Intel Core i7 2.9GHz  16GB               512GB SSD
# 18              Intel Core i3 7100U 2.4GHz   8GB                 1TB HDD
# 19              Intel Core i5 8250U 1.6GHz   8GB               128GB SSD
# 20             Intel Atom x5-Z8350 1.44GHz   2GB      32GB Flash Storage
# 21             Intel Core i5 7300HQ 2.5GHz   8GB    128GB SSD +  1TB HDD
# 22            AMD E-Series E2-9000e 1.5GHz   4GB               500GB HDD
# 23              Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 24              Intel Core i7 8550U 1.8GHz   8GB               256GB SSD
# 25                Intel Core i3 6006U 2GHz   4GB                 1TB HDD
# 26                    Intel Core i5 1.6GHz   8GB     128GB Flash Storage
# 27              Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 28              Intel Core i7 8650U 1.9GHz   8GB  256GB SSD +  256GB SSD
# 29              Intel Core i5 8250U 1.6GHz   8GB                 1TB HDD
# ...                                    ...   ...                     ...
# 1273            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1274  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
# 1275              Intel Core M 6Y30 0.9GHz   8GB               512GB SSD
# 1276            Intel Core i3 7100U 2.4GHz   6GB                 1TB HDD
# 1277  Intel Celeron Dual Core N3060 1.6GHz   4GB               500GB HDD
# 1278  Intel Celeron Dual Core N3050 1.6GHz   2GB               500GB HDD
# 1279           Intel Core i7 6700HQ 2.6GHz   8GB                 1TB HDD
# 1280             AMD A9-Series 9410 2.9GHz   6GB              1TB Hybrid
# 1281            Intel Core i7 7500U 2.7GHz   8GB                 1TB HDD
# 1282  Intel Celeron Dual Core N3060 1.6GHz   2GB      32GB Flash Storage
# 1283            Intel Core i7 6500U 2.5GHz   4GB               500GB HDD
# 1284            Intel Core i7 6500U 2.5GHz   4GB               128GB SSD
# 1285            Intel Core i7 6500U 2.5GHz  16GB               512GB SSD
# 1286  Intel Celeron Dual Core N3050 1.6GHz   2GB      64GB Flash Storage
# 1287            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1288  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
# 1289              Intel Core M 6Y30 0.9GHz   8GB               512GB SSD
# 1290            Intel Core i3 7100U 2.4GHz   6GB                 1TB HDD
# 1291  Intel Celeron Dual Core N3060 1.6GHz   4GB               500GB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz   2GB               500GB HDD
# 1293           Intel Core i7 6700HQ 2.6GHz   8GB                 1TB HDD
# 1294             AMD A9-Series 9410 2.9GHz   6GB              1TB Hybrid
# 1295            Intel Core i7 7500U 2.7GHz   8GB                 1TB HDD
# 1296  Intel Celeron Dual Core N3060 1.6GHz   2GB      32GB Flash Storage
# 1297            Intel Core i7 6500U 2.5GHz   4GB               500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz   4GB               128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB               512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB      64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
#
#                                GPU Operating System Operating System Version  \
# 0     Intel Iris Plus Graphics 640            macOS                      NaN
# 1           Intel HD Graphics 6000            macOS                      NaN
# 2            Intel HD Graphics 620            No OS                      NaN
# 3               AMD Radeon Pro 455            macOS                      NaN
# 4     Intel Iris Plus Graphics 650            macOS                      NaN
# 5                    AMD Radeon R5          Windows                       10
# 6          Intel Iris Pro Graphics           Mac OS                        X
# 7           Intel HD Graphics 6000            macOS                      NaN
# 8             Nvidia GeForce MX150          Windows                       10
# 9           Intel UHD Graphics 620          Windows                       10
# 10           Intel HD Graphics 620            No OS                      NaN
# 11           Intel HD Graphics 520            No OS                      NaN
# 12              AMD Radeon Pro 555            macOS                      NaN
# 13              AMD Radeon R5 M430          Windows                       10
# 14           Intel HD Graphics 615            macOS                      NaN
# 15    Intel Iris Plus Graphics 640            macOS                      NaN
# 16              AMD Radeon R5 M430          Windows                       10
# 17              AMD Radeon Pro 560            macOS                      NaN
# 18            Nvidia GeForce 940MX            No OS                      NaN
# 19          Intel UHD Graphics 620          Windows                       10
# 20           Intel HD Graphics 400          Windows                       10
# 21         Nvidia GeForce GTX 1050          Windows                       10
# 22                   AMD Radeon R2            No OS                      NaN
# 23          Intel UHD Graphics 620          Windows                       10
# 24           Intel HD Graphics 620          Windows                       10
# 25           Intel HD Graphics 520          Windows                       10
# 26          Intel HD Graphics 6000           Mac OS                        X
# 27                  AMD Radeon 530          Windows                       10
# 28          Intel UHD Graphics 620          Windows                       10
# 29            Nvidia GeForce 930MX          Windows                       10
# ...                            ...              ...                      ...
# 1273            AMD Radeon R5 M330          Windows                       10
# 1274             Intel HD Graphics          Windows                       10
# 1275         Intel HD Graphics 515          Windows                       10
# 1276         Intel HD Graphics 620          Windows                       10
# 1277         Intel HD Graphics 400            Linux                      NaN
# 1278             Intel HD Graphics          Windows                       10
# 1279       Nvidia GeForce GTX 960M          Windows                       10
# 1280            AMD Radeon R7 M440          Windows                       10
# 1281            AMD Radeon R5 M430            Linux                      NaN
# 1282         Intel HD Graphics 400          Windows                       10
# 1283           Nvidia GeForce 920M          Windows                       10
# 1284         Intel HD Graphics 520          Windows                       10
# 1285         Intel HD Graphics 520          Windows                       10
# 1286             Intel HD Graphics          Windows                       10
# 1287            AMD Radeon R5 M330          Windows                       10
# 1288             Intel HD Graphics          Windows                       10
# 1289         Intel HD Graphics 515          Windows                       10
# 1290         Intel HD Graphics 620          Windows                       10
# 1291         Intel HD Graphics 400            Linux                      NaN
# 1292             Intel HD Graphics          Windows                       10
# 1293       Nvidia GeForce GTX 960M          Windows                       10
# 1294            AMD Radeon R7 M440          Windows                       10
# 1295            AMD Radeon R5 M430            Linux                      NaN
# 1296         Intel HD Graphics 400          Windows                       10
# 1297           Nvidia GeForce 920M          Windows                       10
# 1298         Intel HD Graphics 520          Windows                       10
# 1299         Intel HD Graphics 520          Windows                       10
# 1300             Intel HD Graphics          Windows                       10
# 1301            AMD Radeon R5 M330          Windows                       10
# 1302             Intel HD Graphics          Windows                       10
#
#       Weight Price (Euros)
# 0     1.37kg       1339,69
# 1     1.34kg        898,94
# 2     1.86kg        575,00
# 3     1.83kg       2537,45
# 4     1.37kg       1803,60
# 5      2.1kg        400,00
# 6     2.04kg       2139,97
# 7     1.34kg       1158,70
# 8      1.3kg       1495,00
# 9      1.6kg        770,00
# 10    1.86kg        393,90
# 11    1.86kg        344,99
# 12    1.83kg       2439,97
# 13     2.2kg        498,90
# 14    0.92kg       1262,40
# 15    1.37kg       1518,55
# 16     2.2kg        745,00
# 17    1.83kg       2858,00
# 18     2.2kg        499,00
# 19    1.22kg        979,00
# 20    0.98kg        191,90
# 21     2.5kg        999,00
# 22    1.86kg        258,00
# 23    1.62kg        819,00
# 24    1.91kg        659,00
# 25     2.3kg        418,64
# 26    1.35kg       1099,00
# 27     2.2kg        800,00
# 28    1.88kg       1298,00
# 29     2.5kg        896,00
# ...      ...           ...
# 1273  2.19kg        764,00
# 1274   2.2kg        369,00
# 1275   1.2kg        729,00
# 1276   2.3kg        459,00
# 1277   2.4kg        289,00
# 1278  2.20kg        379,00
# 1279   2.6kg        899,00
# 1280  2.04kg        549,99
# 1281   2.3kg        805,99
# 1282  1.17kg        209,00
# 1283   2.2kg        720,32
# 1284   1.8kg        638,00
# 1285   1.3kg       1499,00
# 1286   1.5kg        229,00
# 1287  2.19kg        764,00
# 1288   2.2kg        369,00
# 1289   1.2kg        729,00
# 1290   2.3kg        459,00
# 1291   2.4kg        289,00
# 1292  2.20kg        379,00
# 1293   2.6kg        899,00
# 1294  2.04kg        549,99
# 1295   2.3kg        805,99
# 1296  1.17kg        209,00
# 1297   2.2kg        720,32
# 1298   1.8kg        638,00
# 1299   1.3kg       1499,00
# 1300   1.5kg        229,00
# 1301  2.19kg        764,00
# 1302   2.2kg        369,00
#
# [1303 rows x 13 columns]

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
# Manufacturer                1303 non-null object
# Model Name                  1303 non-null object
# Category                    1303 non-null object
# Screen Size                 1303 non-null object
# Screen                      1303 non-null object
# CPU                         1303 non-null object
# RAM                         1303 non-null object
#  Storage                    1303 non-null object
# GPU                         1303 non-null object
# Operating System            1303 non-null object
# Operating System Version    1133 non-null object
# Weight                      1303 non-null object
# Price (Euros)               1303 non-null object
# dtypes: object(13)
# memory usage: 132.4+ KB

# %% [markdown]
# ## Cleaning Column Names

# %% [markdown]
# We can see that every column is represented as the object type, indicating that they are represented by strings and not numbers. One of the columns, Operating System Version, has some null values.

# %%
laptops.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price (Euros)'],
#       dtype='object')

# %% [markdown]
# The column labels have a variety of upper and lowercase letters, as well as spaces and parentheses. Because we represent column labels as strings, this isn't inherently a problem, but you'll find that uniform column labels will be easier to work with. We'll clean our column labels by:
#
# - Removing any whitespace from the start and end of the labels - if you look closely you'll notice that the " Storage" column label has a space in front of it. These quirks with column labels are often hard to spot, so removing them at the start will save you pain in the long run.
#
# - Replacing spaces with underscores and remove special characters - this will make things consistent, and also allows for the use of dot accessors for those who prefer that.
#
# - Make all labels lowercase - this is good for consistency, and means you'll never have to remember what is capitalized and how.
# Shorten any long column names - this helps to keep your code easier to read, especially when you are using method chaining.

# %%
# This function clean a string label as we described above
def clean_label(s):
    s = s.strip();
    s = s.replace("Operating System", "os")
    s = s.replace(" ", "_")
    s = s.replace("(", "")
    s = s.replace(")", "")
    s = s.lower()
    return s

# %%
# Apply the clean function to each column name
new_label = [clean_label(label) for label in laptops.columns]

# %%
new_label
# Out:
# ['manufacturer',
#  'model_name',
#  'category',
#  'screen_size',
#  'screen',
#  'cpu',
#  'ram',
#  'storage',
#  'gpu',
#  'os',
#  'os_version',
#  'weight',
#  'price_euros']

# %%
laptops.columns = new_label

# %% [markdown]
# ## Converting String Columns to Numeric

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
# manufacturer    1303 non-null object
# model_name      1303 non-null object
# category        1303 non-null object
# screen_size     1303 non-null object
# screen          1303 non-null object
# cpu             1303 non-null object
# ram             1303 non-null object
# storage         1303 non-null object
# gpu             1303 non-null object
# os              1303 non-null object
# os_version      1133 non-null object
# weight          1303 non-null object
# price_euros     1303 non-null object
# dtypes: object(13)
# memory usage: 132.4+ KB

# %%
laptops.head()
# Out:
#   manufacturer   model_name   category screen_size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                screen                         cpu   ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                storage                           gpu     os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS        NaN
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS        NaN
# 2            256GB SSD         Intel HD Graphics 620  No OS        NaN
# 3            512GB SSD            AMD Radeon Pro 455  macOS        NaN
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS        NaN
#
#    weight price_euros
# 0  1.37kg     1339,69
# 1  1.34kg      898,94
# 2  1.86kg      575,00
# 3  1.83kg     2537,45
# 4  1.37kg     1803,60

# %% [markdown]
# We notice that some columns store numeric data but with extra symbol, that make the type of those columns non-numeric. We will remove the extra symbols and convert the type of that columns (object) into numeric type (float). For example, the ram column has extra symbol "GB", the weight has extra symbol "kg"

# %%
laptops.ram.unique()
# Out:
# array(['8GB', '16GB', '4GB', '2GB', '12GB', '6GB', '32GB', '24GB', '64GB'],
#       dtype=object)

# %%
# Remove the GB symbol by slicing each string not included the last two index, and then cast to type int
laptops.ram.str.slice(0, -2).astype('int')
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
# 5        4
# 6       16
# 7        8
# 8       16
# 9        8
# 10       4
# 11       4
# 12      16
# 13       4
# 14       8
# 15       8
# 16       8
# 17      16
# 18       8
# 19       8
# 20       2
# 21       8
# 22       4
# 23       8
# 24       8
# 25       4
# 26       8
# 27       8
# 28       8
# 29       8
#         ..
# 1273     6
# 1274     4
# 1275     8
# 1276     6
# 1277     4
# 1278     2
# 1279     8
# 1280     6
# 1281     8
# 1282     2
# 1283     4
# 1284     4
# 1285    16
# 1286     2
# 1287     6
# 1288     4
# 1289     8
# 1290     6
# 1291     4
# 1292     2
# 1293     8
# 1294     6
# 1295     8
# 1296     2
# 1297     4
# 1298     4
# 1299    16
# 1300     2
# 1301     6
# 1302     4
# Name: ram, Length: 1303, dtype: int64

# %% [markdown]
# We create a new column named ram_gb to store the data of column ram converted to numeric type.

# %%
laptops['ram_gb'] = laptops.ram.str.slice(0, -2).astype('int')

# %%
# Notice the new column created and its type
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 14 columns):
# manufacturer    1303 non-null object
# model_name      1303 non-null object
# category        1303 non-null object
# screen_size     1303 non-null object
# screen          1303 non-null object
# cpu             1303 non-null object
# ram             1303 non-null object
# storage         1303 non-null object
# gpu             1303 non-null object
# os              1303 non-null object
# os_version      1133 non-null object
# weight          1303 non-null object
# price_euros     1303 non-null object
# ram_gb          1303 non-null int64
# dtypes: int64(1), object(13)
# memory usage: 142.6+ KB

# %%
# Clean the price_europe column
laptops["price_euros_num"] = laptops.price_euros.str.replace(",", ".").astype("float")

# %% [markdown]
# Next, we clean the weight column. First, look at this column to find understand it pattern and detect any exception.

# %%
laptops.weight.unique()
# Out:
# array(['1.37kg', '1.34kg', '1.86kg', '1.83kg', '2.1kg', '2.04kg', '1.3kg',
#        '1.6kg', '2.2kg', '0.92kg', '1.22kg', '0.98kg', '2.5kg', '1.62kg',
#        '1.91kg', '2.3kg', '1.35kg', '1.88kg', '1.89kg', '1.65kg',
#        '2.71kg', '1.2kg', '1.44kg', '2.8kg', '2kg', '2.65kg', '2.77kg',
#        '3.2kg', '0.69kg', '1.49kg', '2.4kg', '2.13kg', '2.43kg', '1.7kg',
#        '1.4kg', '1.8kg', '1.9kg', '3kg', '1.252kg', '2.7kg', '2.02kg',
#        '1.63kg', '1.96kg', '1.21kg', '2.45kg', '1.25kg', '1.5kg',
#        '2.62kg', '1.38kg', '1.58kg', '1.85kg', '1.23kg', '1.26kg',
#        '2.16kg', '2.36kg', '2.05kg', '1.32kg', '1.75kg', '0.97kg',
#        '2.9kg', '2.56kg', '1.48kg', '1.74kg', '1.1kg', '1.56kg', '2.03kg',
#        '1.05kg', '4.4kg', '1.90kg', '1.29kg', '2.0kg', '1.95kg', '2.06kg',
#        '1.12kg', '1.42kg', '3.49kg', '3.35kg', '2.23kg', '4.42kg',
#        '2.69kg', '2.37kg', '4.7kg', '3.6kg', '2.08kg', '4.3kg', '1.68kg',
#        '1.41kg', '4.14kg', '2.18kg', '2.24kg', '2.67kg', '2.14kg',
#        '1.36kg', '2.25kg', '2.15kg', '2.19kg', '2.54kg', '3.42kg',
#        '1.28kg', '2.33kg', '1.45kg', '2.79kg', '1.84kg', '2.6kg',
#        '2.26kg', '3.25kg', '1.59kg', '1.13kg', '1.78kg', '1.10kg',
#        '1.15kg', '1.27kg', '1.43kg', '2.31kg', '1.16kg', '1.64kg',
#        '2.17kg', '1.47kg', '3.78kg', '1.79kg', '0.91kg', '1.99kg',
#        '4.33kg', '1.93kg', '1.87kg', '2.63kg', '3.4kg', '3.14kg',
#        '1.94kg', '1.24kg', '4.6kg', '4.5kg', '2.73kg', '1.39kg', '2.29kg',
#        '2.59kg', '2.94kg', '1.14kg', '3.8kg', '3.31kg', '1.09kg',
#        '3.21kg', '1.19kg', '1.98kg', '1.17kg', '4.36kg', '1.71kg',
#        '2.32kg', '4.2kg', '1.55kg', '0.81kg', '1.18kg', '2.72kg',
#        '1.31kg', '0.920kg', '3.74kg', '1.76kg', '1.54kg', '2.83kg',
#        '2.07kg', '2.38kg', '3.58kg', '1.08kg', '2.20kg', '2.75kg',
#        '1.70kg', '2.99kg', '1.11kg', '2.09kg', '4kgs', '3.0kg', '0.99kg',
#        '3.52kg', '2.591kg', '2.21kg', '3.3kg', '2.191kg', '2.34kg',
#        '4.0kg'], dtype=object)

# %%
# Observe the special case
laptops.weight[~laptops.weight.str.match(".*[0-9](kg)$")]
# Out:
# 1061    4kgs
# Name: weight, dtype: object

# %%
# Clean the weight column
laptops.weight.str.replace("kg", "").str.replace("s", "").astype("float")
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
# 5       2.10
# 6       2.04
# 7       1.34
# 8       1.30
# 9       1.60
# 10      1.86
# 11      1.86
# 12      1.83
# 13      2.20
# 14      0.92
# 15      1.37
# 16      2.20
# 17      1.83
# 18      2.20
# 19      1.22
# 20      0.98
# 21      2.50
# 22      1.86
# 23      1.62
# 24      1.91
# 25      2.30
# 26      1.35
# 27      2.20
# 28      1.88
# 29      2.50
#         ...
# 1273    2.19
# 1274    2.20
# 1275    1.20
# 1276    2.30
# 1277    2.40
# 1278    2.20
# 1279    2.60
# 1280    2.04
# 1281    2.30
# 1282    1.17
# 1283    2.20
# 1284    1.80
# 1285    1.30
# 1286    1.50
# 1287    2.19
# 1288    2.20
# 1289    1.20
# 1290    2.30
# 1291    2.40
# 1292    2.20
# 1293    2.60
# 1294    2.04
# 1295    2.30
# 1296    1.17
# 1297    2.20
# 1298    1.80
# 1299    1.30
# 1300    1.50
# 1301    2.19
# 1302    2.20
# Name: weight, Length: 1303, dtype: float64

# %%
# Create a new column for the cleaned data
laptops["weight_kg"] = laptops["weight"].str.replace("kg", "").str.replace("s", "").astype("float")

# %% [markdown]
# With the new numerical columns, we can answer some basic question such as

# %%
# What is the average laptop weight ?
laptops.weight_kg.mean()
# Out:
# 2.0387336914811973

# %%
# What is the average laptop price ?
laptops.price_euros_num.mean()
# Out:
# 1123.6869915579432

# %%
# What is the average Macbook weight ?
laptops.loc[laptops.manufacturer == "Apple", "weight_kg"].mean()
# Out:
# 1.3204761904761906

# %%
# What is the average Macbook price ?
laptops.loc[laptops.manufacturer == "Apple", "price_euros_num"].mean()
# Out:
# 1564.1985714285713

# %% [markdown]
# ## Extracting Values from Strings

# %% [markdown]
# Observing the cpu column, we notice that the manufacturer of the cpu is the first word of the string. We will extract that information and create a new column to store it.

# %%
laptops.cpu.head(10)
# Out:
# 0          Intel Core i5 2.3GHz
# 1          Intel Core i5 1.8GHz
# 2    Intel Core i5 7200U 2.5GHz
# 3          Intel Core i7 2.7GHz
# 4          Intel Core i5 3.1GHz
# 5       AMD A9-Series 9420 3GHz
# 6          Intel Core i7 2.2GHz
# 7          Intel Core i5 1.8GHz
# 8    Intel Core i7 8550U 1.8GHz
# 9    Intel Core i5 8250U 1.6GHz
# Name: cpu, dtype: object

# %%
# Approach 1: Using str.split with expand=True 
laptops.cpu.str.split(expand=True)[0]
# Out:
# 0       Intel
# 1       Intel
# 2       Intel
# 3       Intel
# 4       Intel
# 5         AMD
# 6       Intel
# 7       Intel
# 8       Intel
# 9       Intel
# 10      Intel
# 11      Intel
# 12      Intel
# 13      Intel
# 14      Intel
# 15      Intel
# 16      Intel
# 17      Intel
# 18      Intel
# 19      Intel
# 20      Intel
# 21      Intel
# 22        AMD
# 23      Intel
# 24      Intel
# 25      Intel
# 26      Intel
# 27      Intel
# 28      Intel
# 29      Intel
#         ...
# 1273    Intel
# 1274    Intel
# 1275    Intel
# 1276    Intel
# 1277    Intel
# 1278    Intel
# 1279    Intel
# 1280      AMD
# 1281    Intel
# 1282    Intel
# 1283    Intel
# 1284    Intel
# 1285    Intel
# 1286    Intel
# 1287    Intel
# 1288    Intel
# 1289    Intel
# 1290    Intel
# 1291    Intel
# 1292    Intel
# 1293    Intel
# 1294      AMD
# 1295    Intel
# 1296    Intel
# 1297    Intel
# 1298    Intel
# 1299    Intel
# 1300    Intel
# 1301    Intel
# 1302    Intel
# Name: 0, Length: 1303, dtype: object

# %%
# Approach 2: Using apply function 
laptops.cpu.str.split().apply(lambda x: x[0])
# Out:
# 0       Intel
# 1       Intel
# 2       Intel
# 3       Intel
# 4       Intel
# 5         AMD
# 6       Intel
# 7       Intel
# 8       Intel
# 9       Intel
# 10      Intel
# 11      Intel
# 12      Intel
# 13      Intel
# 14      Intel
# 15      Intel
# 16      Intel
# 17      Intel
# 18      Intel
# 19      Intel
# 20      Intel
# 21      Intel
# 22        AMD
# 23      Intel
# 24      Intel
# 25      Intel
# 26      Intel
# 27      Intel
# 28      Intel
# 29      Intel
#         ...
# 1273    Intel
# 1274    Intel
# 1275    Intel
# 1276    Intel
# 1277    Intel
# 1278    Intel
# 1279    Intel
# 1280      AMD
# 1281    Intel
# 1282    Intel
# 1283    Intel
# 1284    Intel
# 1285    Intel
# 1286    Intel
# 1287    Intel
# 1288    Intel
# 1289    Intel
# 1290    Intel
# 1291    Intel
# 1292    Intel
# 1293    Intel
# 1294      AMD
# 1295    Intel
# 1296    Intel
# 1297    Intel
# 1298    Intel
# 1299    Intel
# 1300    Intel
# 1301    Intel
# 1302    Intel
# Name: cpu, Length: 1303, dtype: object

# %%
# Approach 3: Using regular expression
laptops.cpu.str.extract("(\w*) ", expand=False)
# Out:
# 0       Intel
# 1       Intel
# 2       Intel
# 3       Intel
# 4       Intel
# 5         AMD
# 6       Intel
# 7       Intel
# 8       Intel
# 9       Intel
# 10      Intel
# 11      Intel
# 12      Intel
# 13      Intel
# 14      Intel
# 15      Intel
# 16      Intel
# 17      Intel
# 18      Intel
# 19      Intel
# 20      Intel
# 21      Intel
# 22        AMD
# 23      Intel
# 24      Intel
# 25      Intel
# 26      Intel
# 27      Intel
# 28      Intel
# 29      Intel
#         ...
# 1273    Intel
# 1274    Intel
# 1275    Intel
# 1276    Intel
# 1277    Intel
# 1278    Intel
# 1279    Intel
# 1280      AMD
# 1281    Intel
# 1282    Intel
# 1283    Intel
# 1284    Intel
# 1285    Intel
# 1286    Intel
# 1287    Intel
# 1288    Intel
# 1289    Intel
# 1290    Intel
# 1291    Intel
# 1292    Intel
# 1293    Intel
# 1294      AMD
# 1295    Intel
# 1296    Intel
# 1297    Intel
# 1298    Intel
# 1299    Intel
# 1300    Intel
# 1301    Intel
# 1302    Intel
# Name: cpu, Length: 1303, dtype: object

# %%
laptops["cpu_manufacturer"] = laptops.cpu.str.extract("(\w*) ", expand=False)

# %%
laptops.cpu_manufacturer.value_counts()
# Out:
# Intel      1240
# AMD          62
# Samsung       1
# Name: cpu_manufacturer, dtype: int64

# %% [markdown]
# Next, we want to extract the cpu speed from the cpu column.

# %%
laptops.cpu.str.replace("GHz", "").str.extract(" ([0-9\.]*)$").astype("float")
# Out:
#          0
# 0     2.30
# 1     1.80
# 2     2.50
# 3     2.70
# 4     3.10
# 5     3.00
# 6     2.20
# 7     1.80
# 8     1.80
# 9     1.60
# 10    2.50
# 11    2.00
# 12    2.80
# 13    2.00
# 14    1.20
# 15    2.30
# 16    2.70
# 17    2.90
# 18    2.40
# 19    1.60
# 20    1.44
# 21    2.50
# 22    1.50
# 23    1.60
# 24    1.80
# 25    2.00
# 26    1.60
# 27    1.60
# 28    1.90
# 29    1.60
# ...    ...
# 1273  2.50
# 1274  1.60
# 1275  0.90
# 1276  2.40
# 1277  1.60
# 1278  1.60
# 1279  2.60
# 1280  2.90
# 1281  2.70
# 1282  1.60
# 1283  2.50
# 1284  2.50
# 1285  2.50
# 1286  1.60
# 1287  2.50
# 1288  1.60
# 1289  0.90
# 1290  2.40
# 1291  1.60
# 1292  1.60
# 1293  2.60
# 1294  2.90
# 1295  2.70
# 1296  1.60
# 1297  2.50
# 1298  2.50
# 1299  2.50
# 1300  1.60
# 1301  2.50
# 1302  1.60
#
# [1303 rows x 1 columns]

# %%
laptops["cpu_speed_ghz"] =  laptops.cpu.str.replace("GHz", "").str.extract(" ([0-9\.]*)$").astype("float")

# %%
# What laptops have highest cpu speed ?
laptops[laptops.cpu_speed_ghz == laptops.cpu_speed_ghz.max()]
# Out:
#      manufacturer         model_name  category screen_size             screen  \
# 341        Lenovo  IdeaPad 320-15ABR  Notebook       15.6"  Full HD 1920x1080
# 591        Lenovo  IdeaPad 320-15ABR  Notebook       15.6"  Full HD 1920x1080
# 702        Lenovo  IdeaPad 320-15ABR  Notebook       15.6"           1366x768
# 982        Lenovo  IdeaPad 320-15ABR  Notebook       15.6"  Full HD 1920x1080
# 1240       Lenovo  IdeaPad 320-15ABR  Notebook       15.6"  Full HD 1920x1080
#
#                               cpu   ram    storage             gpu       os  \
# 341   AMD A12-Series 9720P 3.6GHz  12GB    2TB HDD  AMD Radeon 530  Windows
# 591   AMD A12-Series 9720P 3.6GHz  12GB  512GB SSD  AMD Radeon 530  Windows
# 702   AMD A12-Series 9720P 3.6GHz   8GB    1TB HDD   AMD Radeon R7  Windows
# 982   AMD A12-Series 9720P 3.6GHz   6GB  256GB SSD  AMD Radeon 530  Windows
# 1240  AMD A12-Series 9720P 3.6GHz   6GB  256GB SSD  AMD Radeon 530  Windows
#
#      os_version weight price_euros  ram_gb  price_euros_num  weight_kg  \
# 341          10  2.2kg      899,00      12           899.00        2.2
# 591          10  2.2kg      949,00      12           949.00        2.2
# 702          10  2.2kg      429,00       8           429.00        2.2
# 982          10  2.2kg      549,00       6           549.00        2.2
# 1240         10  2.2kg      597,57       6           597.57        2.2
#
#      cpu_manufacturer  cpu_speed_ghz
# 341               AMD            3.6
# 591               AMD            3.6
# 702               AMD            3.6
# 982               AMD            3.6
# 1240              AMD            3.6

# %% [markdown]
# ## Correcting Bad Values

# %%
laptops.os.value_counts()
# Out:
# Windows      1125
# No OS          66
# Linux          62
# Chrome OS      27
# macOS          13
# Mac OS          8
# Android         2
# Name: os, dtype: int64

# %% [markdown]
# We can see that there are two variations on how the Apple operating system macOS exists in our dataset: Mac OS and macOS. We will fix that using Series.map() method.

# %%
mapping = {"Windows": "Windows", "No OS": "No OS", "Linux": "Linux", "Chrome OS": "Chrome OS",
           "macOS": "macOS", "Mac OS": "macOS", "Android": "Android"}

# %%
laptops.os.map(mapping).value_counts()
# Out:
# Windows      1125
# No OS          66
# Linux          62
# Chrome OS      27
# macOS          21
# Android         2
# Name: os, dtype: int64

# %%
laptops['os_new'] = laptops.os.map(mapping)

# %%
laptops.os_new.value_counts()
# Out:
# Windows      1125
# No OS          66
# Linux          62
# Chrome OS      27
# macOS          21
# Android         2
# Name: os_new, dtype: int64

# %% [markdown]
# ## Dropping Missing Values

# %% [markdown]
# To check whether our dataset has null value, we will use to approach:

# %%
# Approach 1: info() method
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 19 columns):
# manufacturer        1303 non-null object
# model_name          1303 non-null object
# category            1303 non-null object
# screen_size         1303 non-null object
# screen              1303 non-null object
# cpu                 1303 non-null object
# ram                 1303 non-null object
# storage             1303 non-null object
# gpu                 1303 non-null object
# os                  1303 non-null object
# os_version          1133 non-null object
# weight              1303 non-null object
# price_euros         1303 non-null object
# ram_gb              1303 non-null int64
# price_euros_num     1303 non-null float64
# weight_kg           1303 non-null float64
# cpu_manufacturer    1303 non-null object
# cpu_speed_ghz       1303 non-null float64
# os_new              1303 non-null object
# dtypes: float64(3), int64(1), object(15)
# memory usage: 193.5+ KB

# %%
laptops.os_version
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5        10
# 6         X
# 7       NaN
# 8        10
# 9        10
# 10      NaN
# 11      NaN
# 12      NaN
# 13       10
# 14      NaN
# 15      NaN
# 16       10
# 17      NaN
# 18      NaN
# 19       10
# 20       10
# 21       10
# 22      NaN
# 23       10
# 24       10
# 25       10
# 26        X
# 27       10
# 28       10
# 29       10
#        ...
# 1273     10
# 1274     10
# 1275     10
# 1276     10
# 1277    NaN
# 1278     10
# 1279     10
# 1280     10
# 1281    NaN
# 1282     10
# 1283     10
# 1284     10
# 1285     10
# 1286     10
# 1287     10
# 1288     10
# 1289     10
# 1290     10
# 1291    NaN
# 1292     10
# 1293     10
# 1294     10
# 1295    NaN
# 1296     10
# 1297     10
# 1298     10
# 1299     10
# 1300     10
# 1301     10
# 1302     10
# Name: os_version, Length: 1303, dtype: object

# %%
# Approach 2: .isnull() method
laptops.isnull() # Check null value at every place
# Out:
#       manufacturer  model_name  category  screen_size  screen    cpu    ram  \
# 0            False       False     False        False   False  False  False
# 1            False       False     False        False   False  False  False
# 2            False       False     False        False   False  False  False
# 3            False       False     False        False   False  False  False
# 4            False       False     False        False   False  False  False
# 5            False       False     False        False   False  False  False
# 6            False       False     False        False   False  False  False
# 7            False       False     False        False   False  False  False
# 8            False       False     False        False   False  False  False
# 9            False       False     False        False   False  False  False
# 10           False       False     False        False   False  False  False
# 11           False       False     False        False   False  False  False
# 12           False       False     False        False   False  False  False
# 13           False       False     False        False   False  False  False
# 14           False       False     False        False   False  False  False
# 15           False       False     False        False   False  False  False
# 16           False       False     False        False   False  False  False
# 17           False       False     False        False   False  False  False
# 18           False       False     False        False   False  False  False
# 19           False       False     False        False   False  False  False
# 20           False       False     False        False   False  False  False
# 21           False       False     False        False   False  False  False
# 22           False       False     False        False   False  False  False
# 23           False       False     False        False   False  False  False
# 24           False       False     False        False   False  False  False
# 25           False       False     False        False   False  False  False
# 26           False       False     False        False   False  False  False
# 27           False       False     False        False   False  False  False
# 28           False       False     False        False   False  False  False
# 29           False       False     False        False   False  False  False
# ...            ...         ...       ...          ...     ...    ...    ...
# 1273         False       False     False        False   False  False  False
# 1274         False       False     False        False   False  False  False
# 1275         False       False     False        False   False  False  False
# 1276         False       False     False        False   False  False  False
# 1277         False       False     False        False   False  False  False
# 1278         False       False     False        False   False  False  False
# 1279         False       False     False        False   False  False  False
# 1280         False       False     False        False   False  False  False
# 1281         False       False     False        False   False  False  False
# 1282         False       False     False        False   False  False  False
# 1283         False       False     False        False   False  False  False
# 1284         False       False     False        False   False  False  False
# 1285         False       False     False        False   False  False  False
# 1286         False       False     False        False   False  False  False
# 1287         False       False     False        False   False  False  False
# 1288         False       False     False        False   False  False  False
# 1289         False       False     False        False   False  False  False
# 1290         False       False     False        False   False  False  False
# 1291         False       False     False        False   False  False  False
# 1292         False       False     False        False   False  False  False
# 1293         False       False     False        False   False  False  False
# 1294         False       False     False        False   False  False  False
# 1295         False       False     False        False   False  False  False
# 1296         False       False     False        False   False  False  False
# 1297         False       False     False        False   False  False  False
# 1298         False       False     False        False   False  False  False
# 1299         False       False     False        False   False  False  False
# 1300         False       False     False        False   False  False  False
# 1301         False       False     False        False   False  False  False
# 1302         False       False     False        False   False  False  False
#
#       storage    gpu     os  os_version  weight  price_euros  ram_gb  \
# 0       False  False  False        True   False        False   False
# 1       False  False  False        True   False        False   False
# 2       False  False  False        True   False        False   False
# 3       False  False  False        True   False        False   False
# 4       False  False  False        True   False        False   False
# 5       False  False  False       False   False        False   False
# 6       False  False  False       False   False        False   False
# 7       False  False  False        True   False        False   False
# 8       False  False  False       False   False        False   False
# 9       False  False  False       False   False        False   False
# 10      False  False  False        True   False        False   False
# 11      False  False  False        True   False        False   False
# 12      False  False  False        True   False        False   False
# 13      False  False  False       False   False        False   False
# 14      False  False  False        True   False        False   False
# 15      False  False  False        True   False        False   False
# 16      False  False  False       False   False        False   False
# 17      False  False  False        True   False        False   False
# 18      False  False  False        True   False        False   False
# 19      False  False  False       False   False        False   False
# 20      False  False  False       False   False        False   False
# 21      False  False  False       False   False        False   False
# 22      False  False  False        True   False        False   False
# 23      False  False  False       False   False        False   False
# 24      False  False  False       False   False        False   False
# 25      False  False  False       False   False        False   False
# 26      False  False  False       False   False        False   False
# 27      False  False  False       False   False        False   False
# 28      False  False  False       False   False        False   False
# 29      False  False  False       False   False        False   False
# ...       ...    ...    ...         ...     ...          ...     ...
# 1273    False  False  False       False   False        False   False
# 1274    False  False  False       False   False        False   False
# 1275    False  False  False       False   False        False   False
# 1276    False  False  False       False   False        False   False
# 1277    False  False  False        True   False        False   False
# 1278    False  False  False       False   False        False   False
# 1279    False  False  False       False   False        False   False
# 1280    False  False  False       False   False        False   False
# 1281    False  False  False        True   False        False   False
# 1282    False  False  False       False   False        False   False
# 1283    False  False  False       False   False        False   False
# 1284    False  False  False       False   False        False   False
# 1285    False  False  False       False   False        False   False
# 1286    False  False  False       False   False        False   False
# 1287    False  False  False       False   False        False   False
# 1288    False  False  False       False   False        False   False
# 1289    False  False  False       False   False        False   False
# 1290    False  False  False       False   False        False   False
# 1291    False  False  False        True   False        False   False
# 1292    False  False  False       False   False        False   False
# 1293    False  False  False       False   False        False   False
# 1294    False  False  False       False   False        False   False
# 1295    False  False  False        True   False        False   False
# 1296    False  False  False       False   False        False   False
# 1297    False  False  False       False   False        False   False
# 1298    False  False  False       False   False        False   False
# 1299    False  False  False       False   False        False   False
# 1300    False  False  False       False   False        False   False
# 1301    False  False  False       False   False        False   False
# 1302    False  False  False       False   False        False   False
#
#       price_euros_num  weight_kg  cpu_manufacturer  cpu_speed_ghz  os_new
# 0               False      False             False          False   False
# 1               False      False             False          False   False
# 2               False      False             False          False   False
# 3               False      False             False          False   False
# 4               False      False             False          False   False
# 5               False      False             False          False   False
# 6               False      False             False          False   False
# 7               False      False             False          False   False
# 8               False      False             False          False   False
# 9               False      False             False          False   False
# 10              False      False             False          False   False
# 11              False      False             False          False   False
# 12              False      False             False          False   False
# 13              False      False             False          False   False
# 14              False      False             False          False   False
# 15              False      False             False          False   False
# 16              False      False             False          False   False
# 17              False      False             False          False   False
# 18              False      False             False          False   False
# 19              False      False             False          False   False
# 20              False      False             False          False   False
# 21              False      False             False          False   False
# 22              False      False             False          False   False
# 23              False      False             False          False   False
# 24              False      False             False          False   False
# 25              False      False             False          False   False
# 26              False      False             False          False   False
# 27              False      False             False          False   False
# 28              False      False             False          False   False
# 29              False      False             False          False   False
# ...               ...        ...               ...            ...     ...
# 1273            False      False             False          False   False
# 1274            False      False             False          False   False
# 1275            False      False             False          False   False
# 1276            False      False             False          False   False
# 1277            False      False             False          False   False
# 1278            False      False             False          False   False
# 1279            False      False             False          False   False
# 1280            False      False             False          False   False
# 1281            False      False             False          False   False
# 1282            False      False             False          False   False
# 1283            False      False             False          False   False
# 1284            False      False             False          False   False
# 1285            False      False             False          False   False
# 1286            False      False             False          False   False
# 1287            False      False             False          False   False
# 1288            False      False             False          False   False
# 1289            False      False             False          False   False
# 1290            False      False             False          False   False
# 1291            False      False             False          False   False
# 1292            False      False             False          False   False
# 1293            False      False             False          False   False
# 1294            False      False             False          False   False
# 1295            False      False             False          False   False
# 1296            False      False             False          False   False
# 1297            False      False             False          False   False
# 1298            False      False             False          False   False
# 1299            False      False             False          False   False
# 1300            False      False             False          False   False
# 1301            False      False             False          False   False
# 1302            False      False             False          False   False
#
# [1303 rows x 19 columns]

# %%
# Check null value on column. Which column has null values ?
laptops.isnull().any()
# Out:
# manufacturer        False
# model_name          False
# category            False
# screen_size         False
# screen              False
# cpu                 False
# ram                 False
# storage             False
# gpu                 False
# os                  False
# os_version           True
# weight              False
# price_euros         False
# ram_gb              False
# price_euros_num     False
# weight_kg           False
# cpu_manufacturer    False
# cpu_speed_ghz       False
# os_new              False
# dtype: bool

# %%
# How many null values in each column ?
laptops.isnull().sum()
# Out:
# manufacturer          0
# model_name            0
# category              0
# screen_size           0
# screen                0
# cpu                   0
# ram                   0
# storage               0
# gpu                   0
# os                    0
# os_version          170
# weight                0
# price_euros           0
# ram_gb                0
# price_euros_num       0
# weight_kg             0
# cpu_manufacturer      0
# cpu_speed_ghz         0
# os_new                0
# dtype: int64

# %% [markdown]
# We have a few options for how we can handle missing values:
#
# - Remove any rows that have missing values.
# - Remove any columns that have missing values.
# - Fill the missing values with some other value.
# - Leave the missing values as is.

# %%
# Remove a null column
laptops.drop(labels='os_version', axis=1)
# Out:
#      manufacturer                                 model_name  \
# 0           Apple                                MacBook Pro
# 1           Apple                                Macbook Air
# 2              HP                                     250 G6
# 3           Apple                                MacBook Pro
# 4           Apple                                MacBook Pro
# 5            Acer                                   Aspire 3
# 6           Apple                                MacBook Pro
# 7           Apple                                Macbook Air
# 8            Asus                            ZenBook UX430UN
# 9            Acer                                    Swift 3
# 10             HP                                     250 G6
# 11             HP                                     250 G6
# 12          Apple                                MacBook Pro
# 13           Dell                              Inspiron 3567
# 14          Apple                                MacBook 12"
# 15          Apple                                MacBook Pro
# 16           Dell                              Inspiron 3567
# 17          Apple                                MacBook Pro
# 18         Lenovo                          IdeaPad 320-15IKB
# 19           Dell                                     XPS 13
# 20           Asus                            Vivobook E200HA
# 21         Lenovo                         Legion Y520-15IKBN
# 22             HP                                     255 G6
# 23           Dell                              Inspiron 5379
# 24             HP    15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)
# 25           Dell                              Inspiron 3567
# 26          Apple                                MacBook Air
# 27           Dell                              Inspiron 5570
# 28           Dell                              Latitude 5590
# 29             HP                                ProBook 470
# ...           ...                                        ...
# 1273           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1274         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 1275         Asus                       ZenBook UX305CA-UBM1
# 1276         Dell                              Inspiron 3567
# 1277         Acer                             Aspire ES1-531
# 1278         Dell                              Inspiron 3552
# 1279       Lenovo                         IdeaPad Y700-15ISK
# 1280           HP                        Pavilion 15-AW003nv
# 1281         Dell                              Inspiron 3567
# 1282           HP                           Stream 11-Y000na
# 1283         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1284       Lenovo                             Yoga 500-14ISK
# 1285       Lenovo                             Yoga 900-13ISK
# 1286       Lenovo                         IdeaPad 100S-14IBR
# 1287           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1288         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 1289         Asus                       ZenBook UX305CA-UBM1
# 1290         Dell                              Inspiron 3567
# 1291         Acer                             Aspire ES1-531
# 1292         Dell                              Inspiron 3552
# 1293       Lenovo                         IdeaPad Y700-15ISK
# 1294           HP                        Pavilion 15-AW003nv
# 1295         Dell                              Inspiron 3567
# 1296           HP                           Stream 11-Y000na
# 1297         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1298       Lenovo                             Yoga 500-14ISK
# 1299       Lenovo                             Yoga 900-13ISK
# 1300       Lenovo                         IdeaPad 100S-14IBR
# 1301           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 category screen_size  \
# 0              Ultrabook       13.3"
# 1              Ultrabook       13.3"
# 2               Notebook       15.6"
# 3              Ultrabook       15.4"
# 4              Ultrabook       13.3"
# 5               Notebook       15.6"
# 6              Ultrabook       15.4"
# 7              Ultrabook       13.3"
# 8              Ultrabook       14.0"
# 9              Ultrabook       14.0"
# 10              Notebook       15.6"
# 11              Notebook       15.6"
# 12             Ultrabook       15.4"
# 13              Notebook       15.6"
# 14             Ultrabook       12.0"
# 15             Ultrabook       13.3"
# 16              Notebook       15.6"
# 17             Ultrabook       15.4"
# 18              Notebook       15.6"
# 19             Ultrabook       13.3"
# 20               Netbook       11.6"
# 21                Gaming       15.6"
# 22              Notebook       15.6"
# 23    2 in 1 Convertible       13.3"
# 24             Ultrabook       15.6"
# 25              Notebook       15.6"
# 26             Ultrabook       13.3"
# 27              Notebook       15.6"
# 28             Ultrabook       15.6"
# 29              Notebook       17.3"
# ...                  ...         ...
# 1273            Notebook       15.6"
# 1274            Notebook       15.6"
# 1275           Ultrabook       13.3"
# 1276            Notebook       15.6"
# 1277            Notebook       15.6"
# 1278            Notebook       15.6"
# 1279            Notebook       15.6"
# 1280            Notebook       15.6"
# 1281            Notebook       15.6"
# 1282             Netbook       11.6"
# 1283            Notebook       15.6"
# 1284  2 in 1 Convertible       14.0"
# 1285  2 in 1 Convertible       13.3"
# 1286            Notebook       14.0"
# 1287            Notebook       15.6"
# 1288            Notebook       15.6"
# 1289           Ultrabook       13.3"
# 1290            Notebook       15.6"
# 1291            Notebook       15.6"
# 1292            Notebook       15.6"
# 1293            Notebook       15.6"
# 1294            Notebook       15.6"
# 1295            Notebook       15.6"
# 1296             Netbook       11.6"
# 1297            Notebook       15.6"
# 1298  2 in 1 Convertible       14.0"
# 1299  2 in 1 Convertible       13.3"
# 1300            Notebook       14.0"
# 1301            Notebook       15.6"
# 1302            Notebook       15.6"
#
#                                           screen  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# 5                                       1366x768
# 6             IPS Panel Retina Display 2880x1800
# 7                                       1440x900
# 8                              Full HD 1920x1080
# 9                    IPS Panel Full HD 1920x1080
# 10                                      1366x768
# 11                             Full HD 1920x1080
# 12            IPS Panel Retina Display 2880x1800
# 13                             Full HD 1920x1080
# 14            IPS Panel Retina Display 2304x1440
# 15            IPS Panel Retina Display 2560x1600
# 16                             Full HD 1920x1080
# 17            IPS Panel Retina Display 2880x1800
# 18                             Full HD 1920x1080
# 19     IPS Panel Full HD / Touchscreen 1920x1080
# 20                                      1366x768
# 21                   IPS Panel Full HD 1920x1080
# 22                                      1366x768
# 23               Full HD / Touchscreen 1920x1080
# 24                             Full HD 1920x1080
# 25                                      1366x768
# 26                                      1440x900
# 27                             Full HD 1920x1080
# 28                             Full HD 1920x1080
# 29                             Full HD 1920x1080
# ...                                          ...
# 1273                                    1366x768
# 1274                                    1366x768
# 1275                 IPS Panel Full HD 1920x1080
# 1276                                    1366x768
# 1277                                    1366x768
# 1278                                    1366x768
# 1279                 IPS Panel Full HD 1920x1080
# 1280                           Full HD 1920x1080
# 1281                                    1366x768
# 1282                                    1366x768
# 1283                                    1366x768
# 1284   IPS Panel Full HD / Touchscreen 1920x1080
# 1285  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1286                                    1366x768
# 1287                                    1366x768
# 1288                                    1366x768
# 1289                 IPS Panel Full HD 1920x1080
# 1290                                    1366x768
# 1291                                    1366x768
# 1292                                    1366x768
# 1293                 IPS Panel Full HD 1920x1080
# 1294                           Full HD 1920x1080
# 1295                                    1366x768
# 1296                                    1366x768
# 1297                                    1366x768
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        cpu   ram                 storage  \
# 0                     Intel Core i5 2.3GHz   8GB               128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB     128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB               256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB               512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB               256GB SSD
# 5                  AMD A9-Series 9420 3GHz   4GB               500GB HDD
# 6                     Intel Core i7 2.2GHz  16GB     256GB Flash Storage
# 7                     Intel Core i5 1.8GHz   8GB     256GB Flash Storage
# 8               Intel Core i7 8550U 1.8GHz  16GB               512GB SSD
# 9               Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 10              Intel Core i5 7200U 2.5GHz   4GB               500GB HDD
# 11                Intel Core i3 6006U 2GHz   4GB               500GB HDD
# 12                    Intel Core i7 2.8GHz  16GB               256GB SSD
# 13                Intel Core i3 6006U 2GHz   4GB               256GB SSD
# 14                  Intel Core M m3 1.2GHz   8GB               256GB SSD
# 15                    Intel Core i5 2.3GHz   8GB               256GB SSD
# 16              Intel Core i7 7500U 2.7GHz   8GB               256GB SSD
# 17                    Intel Core i7 2.9GHz  16GB               512GB SSD
# 18              Intel Core i3 7100U 2.4GHz   8GB                 1TB HDD
# 19              Intel Core i5 8250U 1.6GHz   8GB               128GB SSD
# 20             Intel Atom x5-Z8350 1.44GHz   2GB      32GB Flash Storage
# 21             Intel Core i5 7300HQ 2.5GHz   8GB    128GB SSD +  1TB HDD
# 22            AMD E-Series E2-9000e 1.5GHz   4GB               500GB HDD
# 23              Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 24              Intel Core i7 8550U 1.8GHz   8GB               256GB SSD
# 25                Intel Core i3 6006U 2GHz   4GB                 1TB HDD
# 26                    Intel Core i5 1.6GHz   8GB     128GB Flash Storage
# 27              Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 28              Intel Core i7 8650U 1.9GHz   8GB  256GB SSD +  256GB SSD
# 29              Intel Core i5 8250U 1.6GHz   8GB                 1TB HDD
# ...                                    ...   ...                     ...
# 1273            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1274  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
# 1275              Intel Core M 6Y30 0.9GHz   8GB               512GB SSD
# 1276            Intel Core i3 7100U 2.4GHz   6GB                 1TB HDD
# 1277  Intel Celeron Dual Core N3060 1.6GHz   4GB               500GB HDD
# 1278  Intel Celeron Dual Core N3050 1.6GHz   2GB               500GB HDD
# 1279           Intel Core i7 6700HQ 2.6GHz   8GB                 1TB HDD
# 1280             AMD A9-Series 9410 2.9GHz   6GB              1TB Hybrid
# 1281            Intel Core i7 7500U 2.7GHz   8GB                 1TB HDD
# 1282  Intel Celeron Dual Core N3060 1.6GHz   2GB      32GB Flash Storage
# 1283            Intel Core i7 6500U 2.5GHz   4GB               500GB HDD
# 1284            Intel Core i7 6500U 2.5GHz   4GB               128GB SSD
# 1285            Intel Core i7 6500U 2.5GHz  16GB               512GB SSD
# 1286  Intel Celeron Dual Core N3050 1.6GHz   2GB      64GB Flash Storage
# 1287            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1288  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
# 1289              Intel Core M 6Y30 0.9GHz   8GB               512GB SSD
# 1290            Intel Core i3 7100U 2.4GHz   6GB                 1TB HDD
# 1291  Intel Celeron Dual Core N3060 1.6GHz   4GB               500GB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz   2GB               500GB HDD
# 1293           Intel Core i7 6700HQ 2.6GHz   8GB                 1TB HDD
# 1294             AMD A9-Series 9410 2.9GHz   6GB              1TB Hybrid
# 1295            Intel Core i7 7500U 2.7GHz   8GB                 1TB HDD
# 1296  Intel Celeron Dual Core N3060 1.6GHz   2GB      32GB Flash Storage
# 1297            Intel Core i7 6500U 2.5GHz   4GB               500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz   4GB               128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB               512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB      64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
#
#                                gpu       os  weight price_euros  ram_gb  \
# 0     Intel Iris Plus Graphics 640    macOS  1.37kg     1339,69       8
# 1           Intel HD Graphics 6000    macOS  1.34kg      898,94       8
# 2            Intel HD Graphics 620    No OS  1.86kg      575,00       8
# 3               AMD Radeon Pro 455    macOS  1.83kg     2537,45      16
# 4     Intel Iris Plus Graphics 650    macOS  1.37kg     1803,60       8
# 5                    AMD Radeon R5  Windows   2.1kg      400,00       4
# 6          Intel Iris Pro Graphics   Mac OS  2.04kg     2139,97      16
# 7           Intel HD Graphics 6000    macOS  1.34kg     1158,70       8
# 8             Nvidia GeForce MX150  Windows   1.3kg     1495,00      16
# 9           Intel UHD Graphics 620  Windows   1.6kg      770,00       8
# 10           Intel HD Graphics 620    No OS  1.86kg      393,90       4
# 11           Intel HD Graphics 520    No OS  1.86kg      344,99       4
# 12              AMD Radeon Pro 555    macOS  1.83kg     2439,97      16
# 13              AMD Radeon R5 M430  Windows   2.2kg      498,90       4
# 14           Intel HD Graphics 615    macOS  0.92kg     1262,40       8
# 15    Intel Iris Plus Graphics 640    macOS  1.37kg     1518,55       8
# 16              AMD Radeon R5 M430  Windows   2.2kg      745,00       8
# 17              AMD Radeon Pro 560    macOS  1.83kg     2858,00      16
# 18            Nvidia GeForce 940MX    No OS   2.2kg      499,00       8
# 19          Intel UHD Graphics 620  Windows  1.22kg      979,00       8
# 20           Intel HD Graphics 400  Windows  0.98kg      191,90       2
# 21         Nvidia GeForce GTX 1050  Windows   2.5kg      999,00       8
# 22                   AMD Radeon R2    No OS  1.86kg      258,00       4
# 23          Intel UHD Graphics 620  Windows  1.62kg      819,00       8
# 24           Intel HD Graphics 620  Windows  1.91kg      659,00       8
# 25           Intel HD Graphics 520  Windows   2.3kg      418,64       4
# 26          Intel HD Graphics 6000   Mac OS  1.35kg     1099,00       8
# 27                  AMD Radeon 530  Windows   2.2kg      800,00       8
# 28          Intel UHD Graphics 620  Windows  1.88kg     1298,00       8
# 29            Nvidia GeForce 930MX  Windows   2.5kg      896,00       8
# ...                            ...      ...     ...         ...     ...
# 1273            AMD Radeon R5 M330  Windows  2.19kg      764,00       6
# 1274             Intel HD Graphics  Windows   2.2kg      369,00       4
# 1275         Intel HD Graphics 515  Windows   1.2kg      729,00       8
# 1276         Intel HD Graphics 620  Windows   2.3kg      459,00       6
# 1277         Intel HD Graphics 400    Linux   2.4kg      289,00       4
# 1278             Intel HD Graphics  Windows  2.20kg      379,00       2
# 1279       Nvidia GeForce GTX 960M  Windows   2.6kg      899,00       8
# 1280            AMD Radeon R7 M440  Windows  2.04kg      549,99       6
# 1281            AMD Radeon R5 M430    Linux   2.3kg      805,99       8
# 1282         Intel HD Graphics 400  Windows  1.17kg      209,00       2
# 1283           Nvidia GeForce 920M  Windows   2.2kg      720,32       4
# 1284         Intel HD Graphics 520  Windows   1.8kg      638,00       4
# 1285         Intel HD Graphics 520  Windows   1.3kg     1499,00      16
# 1286             Intel HD Graphics  Windows   1.5kg      229,00       2
# 1287            AMD Radeon R5 M330  Windows  2.19kg      764,00       6
# 1288             Intel HD Graphics  Windows   2.2kg      369,00       4
# 1289         Intel HD Graphics 515  Windows   1.2kg      729,00       8
# 1290         Intel HD Graphics 620  Windows   2.3kg      459,00       6
# 1291         Intel HD Graphics 400    Linux   2.4kg      289,00       4
# 1292             Intel HD Graphics  Windows  2.20kg      379,00       2
# 1293       Nvidia GeForce GTX 960M  Windows   2.6kg      899,00       8
# 1294            AMD Radeon R7 M440  Windows  2.04kg      549,99       6
# 1295            AMD Radeon R5 M430    Linux   2.3kg      805,99       8
# 1296         Intel HD Graphics 400  Windows  1.17kg      209,00       2
# 1297           Nvidia GeForce 920M  Windows   2.2kg      720,32       4
# 1298         Intel HD Graphics 520  Windows   1.8kg      638,00       4
# 1299         Intel HD Graphics 520  Windows   1.3kg     1499,00      16
# 1300             Intel HD Graphics  Windows   1.5kg      229,00       2
# 1301            AMD Radeon R5 M330  Windows  2.19kg      764,00       6
# 1302             Intel HD Graphics  Windows   2.2kg      369,00       4
#
#       price_euros_num  weight_kg cpu_manufacturer  cpu_speed_ghz   os_new
# 0             1339.69       1.37            Intel           2.30    macOS
# 1              898.94       1.34            Intel           1.80    macOS
# 2              575.00       1.86            Intel           2.50    No OS
# 3             2537.45       1.83            Intel           2.70    macOS
# 4             1803.60       1.37            Intel           3.10    macOS
# 5              400.00       2.10              AMD           3.00  Windows
# 6             2139.97       2.04            Intel           2.20    macOS
# 7             1158.70       1.34            Intel           1.80    macOS
# 8             1495.00       1.30            Intel           1.80  Windows
# 9              770.00       1.60            Intel           1.60  Windows
# 10             393.90       1.86            Intel           2.50    No OS
# 11             344.99       1.86            Intel           2.00    No OS
# 12            2439.97       1.83            Intel           2.80    macOS
# 13             498.90       2.20            Intel           2.00  Windows
# 14            1262.40       0.92            Intel           1.20    macOS
# 15            1518.55       1.37            Intel           2.30    macOS
# 16             745.00       2.20            Intel           2.70  Windows
# 17            2858.00       1.83            Intel           2.90    macOS
# 18             499.00       2.20            Intel           2.40    No OS
# 19             979.00       1.22            Intel           1.60  Windows
# 20             191.90       0.98            Intel           1.44  Windows
# 21             999.00       2.50            Intel           2.50  Windows
# 22             258.00       1.86              AMD           1.50    No OS
# 23             819.00       1.62            Intel           1.60  Windows
# 24             659.00       1.91            Intel           1.80  Windows
# 25             418.64       2.30            Intel           2.00  Windows
# 26            1099.00       1.35            Intel           1.60    macOS
# 27             800.00       2.20            Intel           1.60  Windows
# 28            1298.00       1.88            Intel           1.90  Windows
# 29             896.00       2.50            Intel           1.60  Windows
# ...               ...        ...              ...            ...      ...
# 1273           764.00       2.19            Intel           2.50  Windows
# 1274           369.00       2.20            Intel           1.60  Windows
# 1275           729.00       1.20            Intel           0.90  Windows
# 1276           459.00       2.30            Intel           2.40  Windows
# 1277           289.00       2.40            Intel           1.60    Linux
# 1278           379.00       2.20            Intel           1.60  Windows
# 1279           899.00       2.60            Intel           2.60  Windows
# 1280           549.99       2.04              AMD           2.90  Windows
# 1281           805.99       2.30            Intel           2.70    Linux
# 1282           209.00       1.17            Intel           1.60  Windows
# 1283           720.32       2.20            Intel           2.50  Windows
# 1284           638.00       1.80            Intel           2.50  Windows
# 1285          1499.00       1.30            Intel           2.50  Windows
# 1286           229.00       1.50            Intel           1.60  Windows
# 1287           764.00       2.19            Intel           2.50  Windows
# 1288           369.00       2.20            Intel           1.60  Windows
# 1289           729.00       1.20            Intel           0.90  Windows
# 1290           459.00       2.30            Intel           2.40  Windows
# 1291           289.00       2.40            Intel           1.60    Linux
# 1292           379.00       2.20            Intel           1.60  Windows
# 1293           899.00       2.60            Intel           2.60  Windows
# 1294           549.99       2.04              AMD           2.90  Windows
# 1295           805.99       2.30            Intel           2.70    Linux
# 1296           209.00       1.17            Intel           1.60  Windows
# 1297           720.32       2.20            Intel           2.50  Windows
# 1298           638.00       1.80            Intel           2.50  Windows
# 1299          1499.00       1.30            Intel           2.50  Windows
# 1300           229.00       1.50            Intel           1.60  Windows
# 1301           764.00       2.19            Intel           2.50  Windows
# 1302           369.00       2.20            Intel           1.60  Windows
#
# [1303 rows x 18 columns]

# %%
# Remove all columns with null values
laptops.dropna(axis=1)
# Out:
#      manufacturer                                 model_name  \
# 0           Apple                                MacBook Pro
# 1           Apple                                Macbook Air
# 2              HP                                     250 G6
# 3           Apple                                MacBook Pro
# 4           Apple                                MacBook Pro
# 5            Acer                                   Aspire 3
# 6           Apple                                MacBook Pro
# 7           Apple                                Macbook Air
# 8            Asus                            ZenBook UX430UN
# 9            Acer                                    Swift 3
# 10             HP                                     250 G6
# 11             HP                                     250 G6
# 12          Apple                                MacBook Pro
# 13           Dell                              Inspiron 3567
# 14          Apple                                MacBook 12"
# 15          Apple                                MacBook Pro
# 16           Dell                              Inspiron 3567
# 17          Apple                                MacBook Pro
# 18         Lenovo                          IdeaPad 320-15IKB
# 19           Dell                                     XPS 13
# 20           Asus                            Vivobook E200HA
# 21         Lenovo                         Legion Y520-15IKBN
# 22             HP                                     255 G6
# 23           Dell                              Inspiron 5379
# 24             HP    15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)
# 25           Dell                              Inspiron 3567
# 26          Apple                                MacBook Air
# 27           Dell                              Inspiron 5570
# 28           Dell                              Latitude 5590
# 29             HP                                ProBook 470
# ...           ...                                        ...
# 1273           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1274         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 1275         Asus                       ZenBook UX305CA-UBM1
# 1276         Dell                              Inspiron 3567
# 1277         Acer                             Aspire ES1-531
# 1278         Dell                              Inspiron 3552
# 1279       Lenovo                         IdeaPad Y700-15ISK
# 1280           HP                        Pavilion 15-AW003nv
# 1281         Dell                              Inspiron 3567
# 1282           HP                           Stream 11-Y000na
# 1283         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1284       Lenovo                             Yoga 500-14ISK
# 1285       Lenovo                             Yoga 900-13ISK
# 1286       Lenovo                         IdeaPad 100S-14IBR
# 1287           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1288         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 1289         Asus                       ZenBook UX305CA-UBM1
# 1290         Dell                              Inspiron 3567
# 1291         Acer                             Aspire ES1-531
# 1292         Dell                              Inspiron 3552
# 1293       Lenovo                         IdeaPad Y700-15ISK
# 1294           HP                        Pavilion 15-AW003nv
# 1295         Dell                              Inspiron 3567
# 1296           HP                           Stream 11-Y000na
# 1297         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1298       Lenovo                             Yoga 500-14ISK
# 1299       Lenovo                             Yoga 900-13ISK
# 1300       Lenovo                         IdeaPad 100S-14IBR
# 1301           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 category screen_size  \
# 0              Ultrabook       13.3"
# 1              Ultrabook       13.3"
# 2               Notebook       15.6"
# 3              Ultrabook       15.4"
# 4              Ultrabook       13.3"
# 5               Notebook       15.6"
# 6              Ultrabook       15.4"
# 7              Ultrabook       13.3"
# 8              Ultrabook       14.0"
# 9              Ultrabook       14.0"
# 10              Notebook       15.6"
# 11              Notebook       15.6"
# 12             Ultrabook       15.4"
# 13              Notebook       15.6"
# 14             Ultrabook       12.0"
# 15             Ultrabook       13.3"
# 16              Notebook       15.6"
# 17             Ultrabook       15.4"
# 18              Notebook       15.6"
# 19             Ultrabook       13.3"
# 20               Netbook       11.6"
# 21                Gaming       15.6"
# 22              Notebook       15.6"
# 23    2 in 1 Convertible       13.3"
# 24             Ultrabook       15.6"
# 25              Notebook       15.6"
# 26             Ultrabook       13.3"
# 27              Notebook       15.6"
# 28             Ultrabook       15.6"
# 29              Notebook       17.3"
# ...                  ...         ...
# 1273            Notebook       15.6"
# 1274            Notebook       15.6"
# 1275           Ultrabook       13.3"
# 1276            Notebook       15.6"
# 1277            Notebook       15.6"
# 1278            Notebook       15.6"
# 1279            Notebook       15.6"
# 1280            Notebook       15.6"
# 1281            Notebook       15.6"
# 1282             Netbook       11.6"
# 1283            Notebook       15.6"
# 1284  2 in 1 Convertible       14.0"
# 1285  2 in 1 Convertible       13.3"
# 1286            Notebook       14.0"
# 1287            Notebook       15.6"
# 1288            Notebook       15.6"
# 1289           Ultrabook       13.3"
# 1290            Notebook       15.6"
# 1291            Notebook       15.6"
# 1292            Notebook       15.6"
# 1293            Notebook       15.6"
# 1294            Notebook       15.6"
# 1295            Notebook       15.6"
# 1296             Netbook       11.6"
# 1297            Notebook       15.6"
# 1298  2 in 1 Convertible       14.0"
# 1299  2 in 1 Convertible       13.3"
# 1300            Notebook       14.0"
# 1301            Notebook       15.6"
# 1302            Notebook       15.6"
#
#                                           screen  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# 5                                       1366x768
# 6             IPS Panel Retina Display 2880x1800
# 7                                       1440x900
# 8                              Full HD 1920x1080
# 9                    IPS Panel Full HD 1920x1080
# 10                                      1366x768
# 11                             Full HD 1920x1080
# 12            IPS Panel Retina Display 2880x1800
# 13                             Full HD 1920x1080
# 14            IPS Panel Retina Display 2304x1440
# 15            IPS Panel Retina Display 2560x1600
# 16                             Full HD 1920x1080
# 17            IPS Panel Retina Display 2880x1800
# 18                             Full HD 1920x1080
# 19     IPS Panel Full HD / Touchscreen 1920x1080
# 20                                      1366x768
# 21                   IPS Panel Full HD 1920x1080
# 22                                      1366x768
# 23               Full HD / Touchscreen 1920x1080
# 24                             Full HD 1920x1080
# 25                                      1366x768
# 26                                      1440x900
# 27                             Full HD 1920x1080
# 28                             Full HD 1920x1080
# 29                             Full HD 1920x1080
# ...                                          ...
# 1273                                    1366x768
# 1274                                    1366x768
# 1275                 IPS Panel Full HD 1920x1080
# 1276                                    1366x768
# 1277                                    1366x768
# 1278                                    1366x768
# 1279                 IPS Panel Full HD 1920x1080
# 1280                           Full HD 1920x1080
# 1281                                    1366x768
# 1282                                    1366x768
# 1283                                    1366x768
# 1284   IPS Panel Full HD / Touchscreen 1920x1080
# 1285  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1286                                    1366x768
# 1287                                    1366x768
# 1288                                    1366x768
# 1289                 IPS Panel Full HD 1920x1080
# 1290                                    1366x768
# 1291                                    1366x768
# 1292                                    1366x768
# 1293                 IPS Panel Full HD 1920x1080
# 1294                           Full HD 1920x1080
# 1295                                    1366x768
# 1296                                    1366x768
# 1297                                    1366x768
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        cpu   ram                 storage  \
# 0                     Intel Core i5 2.3GHz   8GB               128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB     128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB               256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB               512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB               256GB SSD
# 5                  AMD A9-Series 9420 3GHz   4GB               500GB HDD
# 6                     Intel Core i7 2.2GHz  16GB     256GB Flash Storage
# 7                     Intel Core i5 1.8GHz   8GB     256GB Flash Storage
# 8               Intel Core i7 8550U 1.8GHz  16GB               512GB SSD
# 9               Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 10              Intel Core i5 7200U 2.5GHz   4GB               500GB HDD
# 11                Intel Core i3 6006U 2GHz   4GB               500GB HDD
# 12                    Intel Core i7 2.8GHz  16GB               256GB SSD
# 13                Intel Core i3 6006U 2GHz   4GB               256GB SSD
# 14                  Intel Core M m3 1.2GHz   8GB               256GB SSD
# 15                    Intel Core i5 2.3GHz   8GB               256GB SSD
# 16              Intel Core i7 7500U 2.7GHz   8GB               256GB SSD
# 17                    Intel Core i7 2.9GHz  16GB               512GB SSD
# 18              Intel Core i3 7100U 2.4GHz   8GB                 1TB HDD
# 19              Intel Core i5 8250U 1.6GHz   8GB               128GB SSD
# 20             Intel Atom x5-Z8350 1.44GHz   2GB      32GB Flash Storage
# 21             Intel Core i5 7300HQ 2.5GHz   8GB    128GB SSD +  1TB HDD
# 22            AMD E-Series E2-9000e 1.5GHz   4GB               500GB HDD
# 23              Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 24              Intel Core i7 8550U 1.8GHz   8GB               256GB SSD
# 25                Intel Core i3 6006U 2GHz   4GB                 1TB HDD
# 26                    Intel Core i5 1.6GHz   8GB     128GB Flash Storage
# 27              Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 28              Intel Core i7 8650U 1.9GHz   8GB  256GB SSD +  256GB SSD
# 29              Intel Core i5 8250U 1.6GHz   8GB                 1TB HDD
# ...                                    ...   ...                     ...
# 1273            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1274  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
# 1275              Intel Core M 6Y30 0.9GHz   8GB               512GB SSD
# 1276            Intel Core i3 7100U 2.4GHz   6GB                 1TB HDD
# 1277  Intel Celeron Dual Core N3060 1.6GHz   4GB               500GB HDD
# 1278  Intel Celeron Dual Core N3050 1.6GHz   2GB               500GB HDD
# 1279           Intel Core i7 6700HQ 2.6GHz   8GB                 1TB HDD
# 1280             AMD A9-Series 9410 2.9GHz   6GB              1TB Hybrid
# 1281            Intel Core i7 7500U 2.7GHz   8GB                 1TB HDD
# 1282  Intel Celeron Dual Core N3060 1.6GHz   2GB      32GB Flash Storage
# 1283            Intel Core i7 6500U 2.5GHz   4GB               500GB HDD
# 1284            Intel Core i7 6500U 2.5GHz   4GB               128GB SSD
# 1285            Intel Core i7 6500U 2.5GHz  16GB               512GB SSD
# 1286  Intel Celeron Dual Core N3050 1.6GHz   2GB      64GB Flash Storage
# 1287            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1288  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
# 1289              Intel Core M 6Y30 0.9GHz   8GB               512GB SSD
# 1290            Intel Core i3 7100U 2.4GHz   6GB                 1TB HDD
# 1291  Intel Celeron Dual Core N3060 1.6GHz   4GB               500GB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz   2GB               500GB HDD
# 1293           Intel Core i7 6700HQ 2.6GHz   8GB                 1TB HDD
# 1294             AMD A9-Series 9410 2.9GHz   6GB              1TB Hybrid
# 1295            Intel Core i7 7500U 2.7GHz   8GB                 1TB HDD
# 1296  Intel Celeron Dual Core N3060 1.6GHz   2GB      32GB Flash Storage
# 1297            Intel Core i7 6500U 2.5GHz   4GB               500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz   4GB               128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB               512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB      64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
#
#                                gpu       os  weight price_euros  ram_gb  \
# 0     Intel Iris Plus Graphics 640    macOS  1.37kg     1339,69       8
# 1           Intel HD Graphics 6000    macOS  1.34kg      898,94       8
# 2            Intel HD Graphics 620    No OS  1.86kg      575,00       8
# 3               AMD Radeon Pro 455    macOS  1.83kg     2537,45      16
# 4     Intel Iris Plus Graphics 650    macOS  1.37kg     1803,60       8
# 5                    AMD Radeon R5  Windows   2.1kg      400,00       4
# 6          Intel Iris Pro Graphics   Mac OS  2.04kg     2139,97      16
# 7           Intel HD Graphics 6000    macOS  1.34kg     1158,70       8
# 8             Nvidia GeForce MX150  Windows   1.3kg     1495,00      16
# 9           Intel UHD Graphics 620  Windows   1.6kg      770,00       8
# 10           Intel HD Graphics 620    No OS  1.86kg      393,90       4
# 11           Intel HD Graphics 520    No OS  1.86kg      344,99       4
# 12              AMD Radeon Pro 555    macOS  1.83kg     2439,97      16
# 13              AMD Radeon R5 M430  Windows   2.2kg      498,90       4
# 14           Intel HD Graphics 615    macOS  0.92kg     1262,40       8
# 15    Intel Iris Plus Graphics 640    macOS  1.37kg     1518,55       8
# 16              AMD Radeon R5 M430  Windows   2.2kg      745,00       8
# 17              AMD Radeon Pro 560    macOS  1.83kg     2858,00      16
# 18            Nvidia GeForce 940MX    No OS   2.2kg      499,00       8
# 19          Intel UHD Graphics 620  Windows  1.22kg      979,00       8
# 20           Intel HD Graphics 400  Windows  0.98kg      191,90       2
# 21         Nvidia GeForce GTX 1050  Windows   2.5kg      999,00       8
# 22                   AMD Radeon R2    No OS  1.86kg      258,00       4
# 23          Intel UHD Graphics 620  Windows  1.62kg      819,00       8
# 24           Intel HD Graphics 620  Windows  1.91kg      659,00       8
# 25           Intel HD Graphics 520  Windows   2.3kg      418,64       4
# 26          Intel HD Graphics 6000   Mac OS  1.35kg     1099,00       8
# 27                  AMD Radeon 530  Windows   2.2kg      800,00       8
# 28          Intel UHD Graphics 620  Windows  1.88kg     1298,00       8
# 29            Nvidia GeForce 930MX  Windows   2.5kg      896,00       8
# ...                            ...      ...     ...         ...     ...
# 1273            AMD Radeon R5 M330  Windows  2.19kg      764,00       6
# 1274             Intel HD Graphics  Windows   2.2kg      369,00       4
# 1275         Intel HD Graphics 515  Windows   1.2kg      729,00       8
# 1276         Intel HD Graphics 620  Windows   2.3kg      459,00       6
# 1277         Intel HD Graphics 400    Linux   2.4kg      289,00       4
# 1278             Intel HD Graphics  Windows  2.20kg      379,00       2
# 1279       Nvidia GeForce GTX 960M  Windows   2.6kg      899,00       8
# 1280            AMD Radeon R7 M440  Windows  2.04kg      549,99       6
# 1281            AMD Radeon R5 M430    Linux   2.3kg      805,99       8
# 1282         Intel HD Graphics 400  Windows  1.17kg      209,00       2
# 1283           Nvidia GeForce 920M  Windows   2.2kg      720,32       4
# 1284         Intel HD Graphics 520  Windows   1.8kg      638,00       4
# 1285         Intel HD Graphics 520  Windows   1.3kg     1499,00      16
# 1286             Intel HD Graphics  Windows   1.5kg      229,00       2
# 1287            AMD Radeon R5 M330  Windows  2.19kg      764,00       6
# 1288             Intel HD Graphics  Windows   2.2kg      369,00       4
# 1289         Intel HD Graphics 515  Windows   1.2kg      729,00       8
# 1290         Intel HD Graphics 620  Windows   2.3kg      459,00       6
# 1291         Intel HD Graphics 400    Linux   2.4kg      289,00       4
# 1292             Intel HD Graphics  Windows  2.20kg      379,00       2
# 1293       Nvidia GeForce GTX 960M  Windows   2.6kg      899,00       8
# 1294            AMD Radeon R7 M440  Windows  2.04kg      549,99       6
# 1295            AMD Radeon R5 M430    Linux   2.3kg      805,99       8
# 1296         Intel HD Graphics 400  Windows  1.17kg      209,00       2
# 1297           Nvidia GeForce 920M  Windows   2.2kg      720,32       4
# 1298         Intel HD Graphics 520  Windows   1.8kg      638,00       4
# 1299         Intel HD Graphics 520  Windows   1.3kg     1499,00      16
# 1300             Intel HD Graphics  Windows   1.5kg      229,00       2
# 1301            AMD Radeon R5 M330  Windows  2.19kg      764,00       6
# 1302             Intel HD Graphics  Windows   2.2kg      369,00       4
#
#       price_euros_num  weight_kg cpu_manufacturer  cpu_speed_ghz   os_new
# 0             1339.69       1.37            Intel           2.30    macOS
# 1              898.94       1.34            Intel           1.80    macOS
# 2              575.00       1.86            Intel           2.50    No OS
# 3             2537.45       1.83            Intel           2.70    macOS
# 4             1803.60       1.37            Intel           3.10    macOS
# 5              400.00       2.10              AMD           3.00  Windows
# 6             2139.97       2.04            Intel           2.20    macOS
# 7             1158.70       1.34            Intel           1.80    macOS
# 8             1495.00       1.30            Intel           1.80  Windows
# 9              770.00       1.60            Intel           1.60  Windows
# 10             393.90       1.86            Intel           2.50    No OS
# 11             344.99       1.86            Intel           2.00    No OS
# 12            2439.97       1.83            Intel           2.80    macOS
# 13             498.90       2.20            Intel           2.00  Windows
# 14            1262.40       0.92            Intel           1.20    macOS
# 15            1518.55       1.37            Intel           2.30    macOS
# 16             745.00       2.20            Intel           2.70  Windows
# 17            2858.00       1.83            Intel           2.90    macOS
# 18             499.00       2.20            Intel           2.40    No OS
# 19             979.00       1.22            Intel           1.60  Windows
# 20             191.90       0.98            Intel           1.44  Windows
# 21             999.00       2.50            Intel           2.50  Windows
# 22             258.00       1.86              AMD           1.50    No OS
# 23             819.00       1.62            Intel           1.60  Windows
# 24             659.00       1.91            Intel           1.80  Windows
# 25             418.64       2.30            Intel           2.00  Windows
# 26            1099.00       1.35            Intel           1.60    macOS
# 27             800.00       2.20            Intel           1.60  Windows
# 28            1298.00       1.88            Intel           1.90  Windows
# 29             896.00       2.50            Intel           1.60  Windows
# ...               ...        ...              ...            ...      ...
# 1273           764.00       2.19            Intel           2.50  Windows
# 1274           369.00       2.20            Intel           1.60  Windows
# 1275           729.00       1.20            Intel           0.90  Windows
# 1276           459.00       2.30            Intel           2.40  Windows
# 1277           289.00       2.40            Intel           1.60    Linux
# 1278           379.00       2.20            Intel           1.60  Windows
# 1279           899.00       2.60            Intel           2.60  Windows
# 1280           549.99       2.04              AMD           2.90  Windows
# 1281           805.99       2.30            Intel           2.70    Linux
# 1282           209.00       1.17            Intel           1.60  Windows
# 1283           720.32       2.20            Intel           2.50  Windows
# 1284           638.00       1.80            Intel           2.50  Windows
# 1285          1499.00       1.30            Intel           2.50  Windows
# 1286           229.00       1.50            Intel           1.60  Windows
# 1287           764.00       2.19            Intel           2.50  Windows
# 1288           369.00       2.20            Intel           1.60  Windows
# 1289           729.00       1.20            Intel           0.90  Windows
# 1290           459.00       2.30            Intel           2.40  Windows
# 1291           289.00       2.40            Intel           1.60    Linux
# 1292           379.00       2.20            Intel           1.60  Windows
# 1293           899.00       2.60            Intel           2.60  Windows
# 1294           549.99       2.04              AMD           2.90  Windows
# 1295           805.99       2.30            Intel           2.70    Linux
# 1296           209.00       1.17            Intel           1.60  Windows
# 1297           720.32       2.20            Intel           2.50  Windows
# 1298           638.00       1.80            Intel           2.50  Windows
# 1299          1499.00       1.30            Intel           2.50  Windows
# 1300           229.00       1.50            Intel           1.60  Windows
# 1301           764.00       2.19            Intel           2.50  Windows
# 1302           369.00       2.20            Intel           1.60  Windows
#
# [1303 rows x 18 columns]

# %%
# Remove all row with null values
laptops.dropna()
# Out:
#      manufacturer                                 model_name  \
# 5            Acer                                   Aspire 3
# 6           Apple                                MacBook Pro
# 8            Asus                            ZenBook UX430UN
# 9            Acer                                    Swift 3
# 13           Dell                              Inspiron 3567
# 16           Dell                              Inspiron 3567
# 19           Dell                                     XPS 13
# 20           Asus                            Vivobook E200HA
# 21         Lenovo                         Legion Y520-15IKBN
# 23           Dell                              Inspiron 5379
# 24             HP    15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)
# 25           Dell                              Inspiron 3567
# 26          Apple                                MacBook Air
# 27           Dell                              Inspiron 5570
# 28           Dell                              Latitude 5590
# 29             HP                                ProBook 470
# 30          Chuwi                              LapBook 15.6"
# 31           Asus       E402WA-GA010T (E2-6110/2GB/32GB/W10)
# 32             HP       17-ak001nv (A6-9220/4GB/500GB/Radeon
# 33           Dell                                     XPS 13
# 34          Apple                                MacBook Air
# 35         Lenovo                         IdeaPad 120S-14IAP
# 37           Dell                              Inspiron 5770
# 38             HP                                     250 G6
# 39             HP                                ProBook 450
# 41           Dell                              Inspiron 7577
# 43           Acer                            Aspire A515-51G
# 44           Dell                              Inspiron 7773
# 47           Asus                                  Rog Strix
# 48           Dell                              Inspiron 3567
# ...           ...                                        ...
# 1269         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1270       Lenovo                             Yoga 500-14ISK
# 1271       Lenovo                             Yoga 900-13ISK
# 1272       Lenovo                         IdeaPad 100S-14IBR
# 1273           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1274         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 1275         Asus                       ZenBook UX305CA-UBM1
# 1276         Dell                              Inspiron 3567
# 1278         Dell                              Inspiron 3552
# 1279       Lenovo                         IdeaPad Y700-15ISK
# 1280           HP                        Pavilion 15-AW003nv
# 1282           HP                           Stream 11-Y000na
# 1283         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1284       Lenovo                             Yoga 500-14ISK
# 1285       Lenovo                             Yoga 900-13ISK
# 1286       Lenovo                         IdeaPad 100S-14IBR
# 1287           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1288         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 1289         Asus                       ZenBook UX305CA-UBM1
# 1290         Dell                              Inspiron 3567
# 1292         Dell                              Inspiron 3552
# 1293       Lenovo                         IdeaPad Y700-15ISK
# 1294           HP                        Pavilion 15-AW003nv
# 1296           HP                           Stream 11-Y000na
# 1297         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1298       Lenovo                             Yoga 500-14ISK
# 1299       Lenovo                             Yoga 900-13ISK
# 1300       Lenovo                         IdeaPad 100S-14IBR
# 1301           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 category screen_size  \
# 5               Notebook       15.6"
# 6              Ultrabook       15.4"
# 8              Ultrabook       14.0"
# 9              Ultrabook       14.0"
# 13              Notebook       15.6"
# 16              Notebook       15.6"
# 19             Ultrabook       13.3"
# 20               Netbook       11.6"
# 21                Gaming       15.6"
# 23    2 in 1 Convertible       13.3"
# 24             Ultrabook       15.6"
# 25              Notebook       15.6"
# 26             Ultrabook       13.3"
# 27              Notebook       15.6"
# 28             Ultrabook       15.6"
# 29              Notebook       17.3"
# 30              Notebook       15.6"
# 31              Notebook       14.0"
# 32              Notebook       17.3"
# 33             Ultrabook       13.3"
# 34             Ultrabook       13.3"
# 35              Notebook       14.0"
# 37              Notebook       17.3"
# 38              Notebook       15.6"
# 39              Notebook       15.6"
# 41                Gaming       15.6"
# 43              Notebook       15.6"
# 44    2 in 1 Convertible       17.3"
# 47                Gaming       17.3"
# 48              Notebook       15.6"
# ...                  ...         ...
# 1269            Notebook       15.6"
# 1270  2 in 1 Convertible       14.0"
# 1271  2 in 1 Convertible       13.3"
# 1272            Notebook       14.0"
# 1273            Notebook       15.6"
# 1274            Notebook       15.6"
# 1275           Ultrabook       13.3"
# 1276            Notebook       15.6"
# 1278            Notebook       15.6"
# 1279            Notebook       15.6"
# 1280            Notebook       15.6"
# 1282             Netbook       11.6"
# 1283            Notebook       15.6"
# 1284  2 in 1 Convertible       14.0"
# 1285  2 in 1 Convertible       13.3"
# 1286            Notebook       14.0"
# 1287            Notebook       15.6"
# 1288            Notebook       15.6"
# 1289           Ultrabook       13.3"
# 1290            Notebook       15.6"
# 1292            Notebook       15.6"
# 1293            Notebook       15.6"
# 1294            Notebook       15.6"
# 1296             Netbook       11.6"
# 1297            Notebook       15.6"
# 1298  2 in 1 Convertible       14.0"
# 1299  2 in 1 Convertible       13.3"
# 1300            Notebook       14.0"
# 1301            Notebook       15.6"
# 1302            Notebook       15.6"
#
#                                           screen  \
# 5                                       1366x768
# 6             IPS Panel Retina Display 2880x1800
# 8                              Full HD 1920x1080
# 9                    IPS Panel Full HD 1920x1080
# 13                             Full HD 1920x1080
# 16                             Full HD 1920x1080
# 19     IPS Panel Full HD / Touchscreen 1920x1080
# 20                                      1366x768
# 21                   IPS Panel Full HD 1920x1080
# 23               Full HD / Touchscreen 1920x1080
# 24                             Full HD 1920x1080
# 25                                      1366x768
# 26                                      1440x900
# 27                             Full HD 1920x1080
# 28                             Full HD 1920x1080
# 29                             Full HD 1920x1080
# 30                             Full HD 1920x1080
# 31                                      1366x768
# 32                             Full HD 1920x1080
# 33              Touchscreen / Quad HD+ 3200x1800
# 34                                      1440x900
# 35                                      1366x768
# 37                   IPS Panel Full HD 1920x1080
# 38                                      1366x768
# 39                             Full HD 1920x1080
# 41                   IPS Panel Full HD 1920x1080
# 43                   IPS Panel Full HD 1920x1080
# 44               Full HD / Touchscreen 1920x1080
# 47                             Full HD 1920x1080
# 48                             Full HD 1920x1080
# ...                                          ...
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# 1271  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1272                                    1366x768
# 1273                                    1366x768
# 1274                                    1366x768
# 1275                 IPS Panel Full HD 1920x1080
# 1276                                    1366x768
# 1278                                    1366x768
# 1279                 IPS Panel Full HD 1920x1080
# 1280                           Full HD 1920x1080
# 1282                                    1366x768
# 1283                                    1366x768
# 1284   IPS Panel Full HD / Touchscreen 1920x1080
# 1285  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1286                                    1366x768
# 1287                                    1366x768
# 1288                                    1366x768
# 1289                 IPS Panel Full HD 1920x1080
# 1290                                    1366x768
# 1292                                    1366x768
# 1293                 IPS Panel Full HD 1920x1080
# 1294                           Full HD 1920x1080
# 1296                                    1366x768
# 1297                                    1366x768
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        cpu   ram                 storage  \
# 5                  AMD A9-Series 9420 3GHz   4GB               500GB HDD
# 6                     Intel Core i7 2.2GHz  16GB     256GB Flash Storage
# 8               Intel Core i7 8550U 1.8GHz  16GB               512GB SSD
# 9               Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 13                Intel Core i3 6006U 2GHz   4GB               256GB SSD
# 16              Intel Core i7 7500U 2.7GHz   8GB               256GB SSD
# 19              Intel Core i5 8250U 1.6GHz   8GB               128GB SSD
# 20             Intel Atom x5-Z8350 1.44GHz   2GB      32GB Flash Storage
# 21             Intel Core i5 7300HQ 2.5GHz   8GB    128GB SSD +  1TB HDD
# 23              Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 24              Intel Core i7 8550U 1.8GHz   8GB               256GB SSD
# 25                Intel Core i3 6006U 2GHz   4GB                 1TB HDD
# 26                    Intel Core i5 1.6GHz   8GB     128GB Flash Storage
# 27              Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 28              Intel Core i7 8650U 1.9GHz   8GB  256GB SSD +  256GB SSD
# 29              Intel Core i5 8250U 1.6GHz   8GB                 1TB HDD
# 30             Intel Atom x5-Z8300 1.44GHz   4GB      64GB Flash Storage
# 31             AMD E-Series E2-6110 1.5GHz   2GB      32GB Flash Storage
# 32               AMD A6-Series 9220 2.5GHz   4GB               500GB HDD
# 33              Intel Core i7 8550U 1.8GHz  16GB               512GB SSD
# 34                    Intel Core i5 1.6GHz   8GB     256GB Flash Storage
# 35    Intel Celeron Dual Core N3350 1.1GHz   4GB      64GB Flash Storage
# 37              Intel Core i5 8250U 1.6GHz   8GB    128GB SSD +  1TB HDD
# 38              Intel Core i5 7200U 2.5GHz   4GB                 1TB HDD
# 39              Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 41             Intel Core i7 7700HQ 2.8GHz  16GB    256GB SSD +  1TB HDD
# 43              Intel Core i5 8250U 1.6GHz   4GB               256GB SSD
# 44              Intel Core i5 8250U 1.6GHz  12GB                 1TB HDD
# 47                     AMD Ryzen 1700 3GHz   8GB    256GB SSD +  1TB HDD
# 48              Intel Core i5 7200U 2.5GHz   4GB               256GB SSD
# ...                                    ...   ...                     ...
# 1269            Intel Core i7 6500U 2.5GHz   4GB               500GB HDD
# 1270            Intel Core i7 6500U 2.5GHz   4GB               128GB SSD
# 1271            Intel Core i7 6500U 2.5GHz  16GB               512GB SSD
# 1272  Intel Celeron Dual Core N3050 1.6GHz   2GB      64GB Flash Storage
# 1273            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1274  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
# 1275              Intel Core M 6Y30 0.9GHz   8GB               512GB SSD
# 1276            Intel Core i3 7100U 2.4GHz   6GB                 1TB HDD
# 1278  Intel Celeron Dual Core N3050 1.6GHz   2GB               500GB HDD
# 1279           Intel Core i7 6700HQ 2.6GHz   8GB                 1TB HDD
# 1280             AMD A9-Series 9410 2.9GHz   6GB              1TB Hybrid
# 1282  Intel Celeron Dual Core N3060 1.6GHz   2GB      32GB Flash Storage
# 1283            Intel Core i7 6500U 2.5GHz   4GB               500GB HDD
# 1284            Intel Core i7 6500U 2.5GHz   4GB               128GB SSD
# 1285            Intel Core i7 6500U 2.5GHz  16GB               512GB SSD
# 1286  Intel Celeron Dual Core N3050 1.6GHz   2GB      64GB Flash Storage
# 1287            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1288  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
# 1289              Intel Core M 6Y30 0.9GHz   8GB               512GB SSD
# 1290            Intel Core i3 7100U 2.4GHz   6GB                 1TB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz   2GB               500GB HDD
# 1293           Intel Core i7 6700HQ 2.6GHz   8GB                 1TB HDD
# 1294             AMD A9-Series 9410 2.9GHz   6GB              1TB Hybrid
# 1296  Intel Celeron Dual Core N3060 1.6GHz   2GB      32GB Flash Storage
# 1297            Intel Core i7 6500U 2.5GHz   4GB               500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz   4GB               128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB               512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB      64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
#
#                           gpu       os os_version  weight price_euros  ram_gb  \
# 5               AMD Radeon R5  Windows         10   2.1kg      400,00       4
# 6     Intel Iris Pro Graphics   Mac OS          X  2.04kg     2139,97      16
# 8        Nvidia GeForce MX150  Windows         10   1.3kg     1495,00      16
# 9      Intel UHD Graphics 620  Windows         10   1.6kg      770,00       8
# 13         AMD Radeon R5 M430  Windows         10   2.2kg      498,90       4
# 16         AMD Radeon R5 M430  Windows         10   2.2kg      745,00       8
# 19     Intel UHD Graphics 620  Windows         10  1.22kg      979,00       8
# 20      Intel HD Graphics 400  Windows         10  0.98kg      191,90       2
# 21    Nvidia GeForce GTX 1050  Windows         10   2.5kg      999,00       8
# 23     Intel UHD Graphics 620  Windows         10  1.62kg      819,00       8
# 24      Intel HD Graphics 620  Windows         10  1.91kg      659,00       8
# 25      Intel HD Graphics 520  Windows         10   2.3kg      418,64       4
# 26     Intel HD Graphics 6000   Mac OS          X  1.35kg     1099,00       8
# 27             AMD Radeon 530  Windows         10   2.2kg      800,00       8
# 28     Intel UHD Graphics 620  Windows         10  1.88kg     1298,00       8
# 29       Nvidia GeForce 930MX  Windows         10   2.5kg      896,00       8
# 30          Intel HD Graphics  Windows         10  1.89kg      244,99       4
# 31              AMD Radeon R2  Windows         10  1.65kg      199,00       2
# 32             AMD Radeon 530  Windows         10  2.71kg      439,00       4
# 33     Intel UHD Graphics 620  Windows         10   1.2kg     1869,00      16
# 34     Intel HD Graphics 6000   Mac OS          X  1.35kg      998,00       8
# 35      Intel HD Graphics 500  Windows         10  1.44kg      249,00       4
# 37             AMD Radeon 530  Windows         10   2.8kg      979,00       8
# 38      Intel HD Graphics 620  Windows         10  1.86kg      488,69       4
# 39      Nvidia GeForce 930MX   Windows         10   2.1kg      879,00       8
# 41    Nvidia GeForce GTX 1060  Windows         10  2.65kg     1499,00      16
# 43     Intel UHD Graphics 620  Windows         10   2.2kg      682,00       4
# 44       Nvidia GeForce 150MX  Windows         10  2.77kg      999,00      12
# 47          AMD Radeon RX 580  Windows         10   3.2kg     1299,00       8
# 48         AMD Radeon R5 M430  Windows         10   2.3kg      639,00       4
# ...                       ...      ...        ...     ...         ...     ...
# 1269      Nvidia GeForce 920M  Windows         10   2.2kg      720,32       4
# 1270    Intel HD Graphics 520  Windows         10   1.8kg      638,00       4
# 1271    Intel HD Graphics 520  Windows         10   1.3kg     1499,00      16
# 1272        Intel HD Graphics  Windows         10   1.5kg      229,00       2
# 1273       AMD Radeon R5 M330  Windows         10  2.19kg      764,00       6
# 1274        Intel HD Graphics  Windows         10   2.2kg      369,00       4
# 1275    Intel HD Graphics 515  Windows         10   1.2kg      729,00       8
# 1276    Intel HD Graphics 620  Windows         10   2.3kg      459,00       6
# 1278        Intel HD Graphics  Windows         10  2.20kg      379,00       2
# 1279  Nvidia GeForce GTX 960M  Windows         10   2.6kg      899,00       8
# 1280       AMD Radeon R7 M440  Windows         10  2.04kg      549,99       6
# 1282    Intel HD Graphics 400  Windows         10  1.17kg      209,00       2
# 1283      Nvidia GeForce 920M  Windows         10   2.2kg      720,32       4
# 1284    Intel HD Graphics 520  Windows         10   1.8kg      638,00       4
# 1285    Intel HD Graphics 520  Windows         10   1.3kg     1499,00      16
# 1286        Intel HD Graphics  Windows         10   1.5kg      229,00       2
# 1287       AMD Radeon R5 M330  Windows         10  2.19kg      764,00       6
# 1288        Intel HD Graphics  Windows         10   2.2kg      369,00       4
# 1289    Intel HD Graphics 515  Windows         10   1.2kg      729,00       8
# 1290    Intel HD Graphics 620  Windows         10   2.3kg      459,00       6
# 1292        Intel HD Graphics  Windows         10  2.20kg      379,00       2
# 1293  Nvidia GeForce GTX 960M  Windows         10   2.6kg      899,00       8
# 1294       AMD Radeon R7 M440  Windows         10  2.04kg      549,99       6
# 1296    Intel HD Graphics 400  Windows         10  1.17kg      209,00       2
# 1297      Nvidia GeForce 920M  Windows         10   2.2kg      720,32       4
# 1298    Intel HD Graphics 520  Windows         10   1.8kg      638,00       4
# 1299    Intel HD Graphics 520  Windows         10   1.3kg     1499,00      16
# 1300        Intel HD Graphics  Windows         10   1.5kg      229,00       2
# 1301       AMD Radeon R5 M330  Windows         10  2.19kg      764,00       6
# 1302        Intel HD Graphics  Windows         10   2.2kg      369,00       4
#
#       price_euros_num  weight_kg cpu_manufacturer  cpu_speed_ghz   os_new
# 5              400.00       2.10              AMD           3.00  Windows
# 6             2139.97       2.04            Intel           2.20    macOS
# 8             1495.00       1.30            Intel           1.80  Windows
# 9              770.00       1.60            Intel           1.60  Windows
# 13             498.90       2.20            Intel           2.00  Windows
# 16             745.00       2.20            Intel           2.70  Windows
# 19             979.00       1.22            Intel           1.60  Windows
# 20             191.90       0.98            Intel           1.44  Windows
# 21             999.00       2.50            Intel           2.50  Windows
# 23             819.00       1.62            Intel           1.60  Windows
# 24             659.00       1.91            Intel           1.80  Windows
# 25             418.64       2.30            Intel           2.00  Windows
# 26            1099.00       1.35            Intel           1.60    macOS
# 27             800.00       2.20            Intel           1.60  Windows
# 28            1298.00       1.88            Intel           1.90  Windows
# 29             896.00       2.50            Intel           1.60  Windows
# 30             244.99       1.89            Intel           1.44  Windows
# 31             199.00       1.65              AMD           1.50  Windows
# 32             439.00       2.71              AMD           2.50  Windows
# 33            1869.00       1.20            Intel           1.80  Windows
# 34             998.00       1.35            Intel           1.60    macOS
# 35             249.00       1.44            Intel           1.10  Windows
# 37             979.00       2.80            Intel           1.60  Windows
# 38             488.69       1.86            Intel           2.50  Windows
# 39             879.00       2.10            Intel           1.60  Windows
# 41            1499.00       2.65            Intel           2.80  Windows
# 43             682.00       2.20            Intel           1.60  Windows
# 44             999.00       2.77            Intel           1.60  Windows
# 47            1299.00       3.20              AMD           3.00  Windows
# 48             639.00       2.30            Intel           2.50  Windows
# ...               ...        ...              ...            ...      ...
# 1269           720.32       2.20            Intel           2.50  Windows
# 1270           638.00       1.80            Intel           2.50  Windows
# 1271          1499.00       1.30            Intel           2.50  Windows
# 1272           229.00       1.50            Intel           1.60  Windows
# 1273           764.00       2.19            Intel           2.50  Windows
# 1274           369.00       2.20            Intel           1.60  Windows
# 1275           729.00       1.20            Intel           0.90  Windows
# 1276           459.00       2.30            Intel           2.40  Windows
# 1278           379.00       2.20            Intel           1.60  Windows
# 1279           899.00       2.60            Intel           2.60  Windows
# 1280           549.99       2.04              AMD           2.90  Windows
# 1282           209.00       1.17            Intel           1.60  Windows
# 1283           720.32       2.20            Intel           2.50  Windows
# 1284           638.00       1.80            Intel           2.50  Windows
# 1285          1499.00       1.30            Intel           2.50  Windows
# 1286           229.00       1.50            Intel           1.60  Windows
# 1287           764.00       2.19            Intel           2.50  Windows
# 1288           369.00       2.20            Intel           1.60  Windows
# 1289           729.00       1.20            Intel           0.90  Windows
# 1290           459.00       2.30            Intel           2.40  Windows
# 1292           379.00       2.20            Intel           1.60  Windows
# 1293           899.00       2.60            Intel           2.60  Windows
# 1294           549.99       2.04              AMD           2.90  Windows
# 1296           209.00       1.17            Intel           1.60  Windows
# 1297           720.32       2.20            Intel           2.50  Windows
# 1298           638.00       1.80            Intel           2.50  Windows
# 1299          1499.00       1.30            Intel           2.50  Windows
# 1300           229.00       1.50            Intel           1.60  Windows
# 1301           764.00       2.19            Intel           2.50  Windows
# 1302           369.00       2.20            Intel           1.60  Windows
#
# [1133 rows x 19 columns]

# %% [markdown]
# ## Filling Missing Values

# %% [markdown]
# Instead of removing 170 rows that have null values in the column os_version, or removing the whole column, we will investigate the missing values in this column and find out how to fill these missing values with meaningful data.

# %%
laptops.os_version.value_counts(dropna=False)
# Out:
# 10      1072
# NaN      170
# 7         45
# 10 S       8
# X          8
# Name: os_version, dtype: int64

# %%
# What are the os of the laptops with null values in os_version ?
laptops.loc[laptops.os_version.isnull(), "os"].value_counts()
# Out:
# No OS        66
# Linux        62
# Chrome OS    27
# macOS        13
# Android       2
# Name: os, dtype: int64

# %% [markdown]
# We see that there are 66 laptops which have no installed os. Obviously, there are no os_version of those laptops.

# %%
# What are the most popular os_version of laptop that run macOS ?
laptops.loc[laptops.os_new == "macOS", "os_version"].value_counts(dropna=False)
# Out:
# NaN    13
# X       8
# Name: os_version, dtype: int64

# %% [markdown]
# So now we will handle the missing values in the os_version as follow:
#
# - For rows where os is "No OS" we fill the os_version of that row with "Non OS"
# - For rows where os is "macOS" we fill "X"

# %%
# Make a copy of laptops and modify values on the copy version
laptops_copy = laptops.copy()

# %%
laptops_copy.loc[laptops.os_new == "No OS", "os_version"] = "No OS"

# %%
laptops_copy.loc[laptops.os_new == "macOS", "os_version"] = "X"

# %%
laptops_copy.os_version.value_counts(dropna=False)
# Out:
# 10       1072
# NaN        91
# No OS      66
# 7          45
# X          21
# 10 S        8
# Name: os_version, dtype: int64

# %%
laptops_copy.dropna(inplace=True)

# %%
laptops_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1212 entries, 0 to 1302
# Data columns (total 19 columns):
# manufacturer        1212 non-null object
# model_name          1212 non-null object
# category            1212 non-null object
# screen_size         1212 non-null object
# screen              1212 non-null object
# cpu                 1212 non-null object
# ram                 1212 non-null object
# storage             1212 non-null object
# gpu                 1212 non-null object
# os                  1212 non-null object
# os_version          1212 non-null object
# weight              1212 non-null object
# price_euros         1212 non-null object
# ram_gb              1212 non-null int64
# price_euros_num     1212 non-null float64
# weight_kg           1212 non-null float64
# cpu_manufacturer    1212 non-null object
# cpu_speed_ghz       1212 non-null float64
# os_new              1212 non-null object
# dtypes: float64(3), int64(1), object(15)
# memory usage: 189.4+ KB

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.rcParams["figure.figsize"] = [8, 6]

# %% [markdown]
# ### Bar Plot for Categorical Data

# %%
laptops.manufacturer.value_counts().plot.bar()

# %%
laptops.category.value_counts().plot.bar()

# %%
laptops.os_new.value_counts().plot.bar()

# %% [markdown]
# ### Histograms for Numerical Data

# %%
laptops.price_euros_num.hist(bins=30)
